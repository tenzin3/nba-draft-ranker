# %% [markdown]
# ### 1. Get NBA Draft Data

# %%
import pandas as pd
from pathlib import Path

current_dir = Path.cwd()
draft_dir = current_dir.parent /"data"/ "drafts"

files = list(draft_dir.glob("draft_20*.csv"))

draft_df = pd.DataFrame()
for file in files:
    curr_df = pd.read_csv(file)
    draft_df = pd.concat([draft_df, curr_df])

draft_df = draft_df.sort_values(by=["SEASON", "OVERALL_PICK"]) 
print(draft_df.shape)
draft_df.head()
# Out:
# (1542, 14)
#    PERSON_ID     PLAYER_NAME  SEASON  ROUND_NUMBER  ROUND_PICK  OVERALL_PICK  \
# 0       2030   Kenyon Martin    2000             1           1             1
# 1       2031  Stromile Swift    2000             1           2             2
# 2       2032    Darius Miles    2000             1           3             3
# 3       2033    Marcus Fizer    2000             1           4             4
# 4       2034     Mike Miller    2000             1           5             5
#
#   DRAFT_TYPE     TEAM_ID    TEAM_CITY  TEAM_NAME TEAM_ABBREVIATION  \
# 0      Draft  1610612751   New Jersey       Nets               NJN
# 1      Draft  1610612763    Vancouver  Grizzlies               VAN
# 2      Draft  1610612746  Los Angeles   Clippers               LAC
# 3      Draft  1610612741      Chicago      Bulls               CHI
# 4      Draft  1610612753      Orlando      Magic               ORL
#
#       ORGANIZATION   ORGANIZATION_TYPE  PLAYER_PROFILE_FLAG
# 0       Cincinnati  College/University                    1
# 1  Louisiana State  College/University                    1
# 2   East St. Louis         High School                    1
# 3       Iowa State  College/University                    1
# 4          Florida  College/University                    1

# %% [markdown]
# ### 2. Get NBA Combine Data

# %%
import pandas as pd
from pathlib import Path

current_dir = Path.cwd()
draft_combine_dir = current_dir.parent /"data"/ "draft_combine"

files = list(draft_combine_dir.glob("draft_combine_20*.csv"))

draft_combine_df = pd.DataFrame()
for file in files:
    curr_df = pd.read_csv(file)
    draft_combine_df = pd.concat([draft_combine_df, curr_df])

draft_combine_df = draft_combine_df.sort_values(by=["SEASON"])
print(draft_combine_df.shape)
draft_combine_df.head()
# Out:
# (1795, 47)
#     SEASON  PLAYER_ID FIRST_NAME LAST_NAME     PLAYER_NAME POSITION  \
# 10    2000       2037      Jamal  Crawford  Jamal Crawford    PG-SG
# 37    2000       2058       Mark    Madsen     Mark Madsen       PF
# 36    2000       2090     Justin      Love     Justin Love    PG-SG
# 35    2000       2061        Dan    Langhi      Dan Langhi       SF
# 34    2000      12144    Brandon     Kurtz   Brandon Kurtz     PF-C
#
#     HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES  \
# 10             76.5              6' 4.5''             NaN
# 37             80.0                6' 8''             NaN
# 36             73.5              6' 1.5''             NaN
# 35             81.0                6' 9''             NaN
# 34             81.5              6' 9.5''             NaN
#
#    HEIGHT_W_SHOES_FT_IN  ...  SPOT_NBA_BREAK_RIGHT  SPOT_NBA_CORNER_RIGHT  \
# 10                  NaN  ...                   NaN                    NaN
# 37                  NaN  ...                   NaN                    NaN
# 36                  NaN  ...                   NaN                    NaN
# 35                  NaN  ...                   NaN                    NaN
# 34                  NaN  ...                   NaN                    NaN
#
#    OFF_DRIB_FIFTEEN_BREAK_LEFT  OFF_DRIB_FIFTEEN_TOP_KEY  \
# 10                         NaN                       NaN
# 37                         NaN                       NaN
# 36                         NaN                       NaN
# 35                         NaN                       NaN
# 34                         NaN                       NaN
#
#    OFF_DRIB_FIFTEEN_BREAK_RIGHT  OFF_DRIB_COLLEGE_BREAK_LEFT  \
# 10                          NaN                          NaN
# 37                          NaN                          NaN
# 36                          NaN                          NaN
# 35                          NaN                          NaN
# 34                          NaN                          NaN
#
#     OFF_DRIB_COLLEGE_TOP_KEY  OFF_DRIB_COLLEGE_BREAK_RIGHT  ON_MOVE_FIFTEEN  \
# 10                       NaN                           NaN              NaN
# 37                       NaN                           NaN              NaN
# 36                       NaN                           NaN              NaN
# 35                       NaN                           NaN              NaN
# 34                       NaN                           NaN              NaN
#
#     ON_MOVE_COLLEGE
# 10              NaN
# 37              NaN
# 36              NaN
# 35              NaN
# 34              NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# ### 3. Get Undrafted Players Data

# %%
# Make sure column types match
draft_df["PERSON_ID"] = draft_df["PERSON_ID"].astype(str)
draft_combine_df["PLAYER_ID"] = draft_combine_df["PLAYER_ID"].astype(str)

# Get the sets
drafted_ids = set(draft_df["PERSON_ID"].unique())
combine_ids = set(draft_combine_df["PLAYER_ID"].unique())

# Players who attended combine but were *not* drafted
undrafted_combine_ids = combine_ids - drafted_ids

# Filter full player rows from combine dataframe
undrafted_combine_players = draft_combine_df[
    draft_combine_df["PLAYER_ID"].isin(undrafted_combine_ids)
].copy()


print(f"Numer of Undrafted players: ", len(undrafted_combine_ids))
undrafted_combine_players.head()
# Out:
# Numer of Undrafted players:  678
#     SEASON PLAYER_ID FIRST_NAME LAST_NAME    PLAYER_NAME POSITION  \
# 36    2000      2090     Justin      Love    Justin Love    PG-SG
# 34    2000     12144    Brandon     Kurtz  Brandon Kurtz     PF-C
# 32    2000     12143     Kenyon     Jones   Kenyon Jones     PF-C
# 31    2000     12142       Nate   Johnson   Nate Johnson       SF
# 29    2000     12141      Jacob    Jaacks   Jacob Jaacks       PF
#
#     HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES  \
# 36            73.50              6' 1.5''             NaN
# 34            81.50              6' 9.5''             NaN
# 32            81.00                6' 9''             NaN
# 31            78.50              6' 6.5''             NaN
# 29            81.25             6' 9.25''             NaN
#
#    HEIGHT_W_SHOES_FT_IN  ...  SPOT_NBA_BREAK_RIGHT  SPOT_NBA_CORNER_RIGHT  \
# 36                  NaN  ...                   NaN                    NaN
# 34                  NaN  ...                   NaN                    NaN
# 32                  NaN  ...                   NaN                    NaN
# 31                  NaN  ...                   NaN                    NaN
# 29                  NaN  ...                   NaN                    NaN
#
#    OFF_DRIB_FIFTEEN_BREAK_LEFT  OFF_DRIB_FIFTEEN_TOP_KEY  \
# 36                         NaN                       NaN
# 34                         NaN                       NaN
# 32                         NaN                       NaN
# 31                         NaN                       NaN
# 29                         NaN                       NaN
#
#    OFF_DRIB_FIFTEEN_BREAK_RIGHT  OFF_DRIB_COLLEGE_BREAK_LEFT  \
# 36                          NaN                          NaN
# 34                          NaN                          NaN
# 32                          NaN                          NaN
# 31                          NaN                          NaN
# 29                          NaN                          NaN
#
#     OFF_DRIB_COLLEGE_TOP_KEY  OFF_DRIB_COLLEGE_BREAK_RIGHT  ON_MOVE_FIFTEEN  \
# 36                       NaN                           NaN              NaN
# 34                       NaN                           NaN              NaN
# 32                       NaN                           NaN              NaN
# 31                       NaN                           NaN              NaN
# 29                       NaN                           NaN              NaN
#
#     ON_MOVE_COLLEGE
# 36              NaN
# 34              NaN
# 32              NaN
# 31              NaN
# 29              NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# ### 4.Scrap from basketball-reference

# %%
import os
import re
import time
import random
import requests
import pandas as pd
from typing import Tuple
from urllib.parse import urlparse

CBB_BASE = "https://www.sports-reference.com"

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
        "(KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
    )
}

def safe_get(session, url, *, retries=6, backoff=2.0, timeout=30):
    """Fully 429-compliant GET with exponential backoff + retry-after."""
    last_exc = None

    for i in range(retries):
        try:
            resp = session.get(url, headers=HEADERS, timeout=timeout)

            if resp.status_code == 429:
                retry_after = resp.headers.get("Retry-After")
                try:
                    delay = int(retry_after)
                except:
                    delay = backoff * (2 ** i) + random.uniform(0.5, 1.5)

                print(f"⚠ 429 at {url}, sleeping {delay:.1f}s")
                time.sleep(delay)
                continue

            resp.raise_for_status()
            return resp

        except Exception as e:
            last_exc = e
            delay = backoff * (2 ** i) + random.uniform(0.5, 1.5)
            print(f"⚠ Error {e}, sleeping {delay:.1f}s")
            time.sleep(delay)

    raise last_exc


def build_cbb_url(first, last):
    """Sports-Reference CBB uses fn-ln-1.html pattern."""
    fn = re.sub(r"[^a-z\s-]", "", first.lower()).replace(" ", "-")
    ln = re.sub(r"[^a-z\s-]", "", last.lower()).replace(" ", "-")
    return f"{CBB_BASE}/cbb/players/{fn}-{ln}-1.html"


def scrape_undrafted_players(df, output_dir="cbb_undrafted") -> Tuple[pd.DataFrame, pd.DataFrame]:

    os.makedirs(output_dir, exist_ok=True)

    session = requests.Session()
    all_rows, summary = [], []

    for i, row in enumerate(df.itertuples(index=False), start=1):
        first = row.FIRST_NAME
        last = row.LAST_NAME
        pid = row.PLAYER_ID

        print(f"[{i}/{len(df)}] {first} {last}")

        url = build_cbb_url(first, last)

        # === Safe GET with 429 protection ===
        try:
            resp = safe_get(session, url)
        except Exception as e:
            print(f"❌ Failed for {first} {last}: {e}")
            summary.append({"PLAYER_ID": pid, "found": False, "url": None})
            continue

        tables = pd.read_html(resp.text, flavor="lxml")

        # find season table
        season_table = None
        for t in tables:
            if "Season" in t.columns:
                season_table = t
                break

        if season_table is None:
            print("⚠ No season table found")
            summary.append({"PLAYER_ID": pid, "found": False, "url": url})
            continue

        # clean
        season_table = season_table[season_table["Season"] != "Season"]
        season_table = season_table[season_table["Season"].notna()]
        season_table = season_table[season_table["Season"] != "Career"]

        if season_table.empty:
            print("⚠ No usable rows")
            summary.append({"PLAYER_ID": pid, "found": False, "url": url})
            continue

        last_row = season_table.tail(1).copy()
        last_row.insert(0, "PLAYER_ID", pid)
        last_row.insert(1, "FIRST_NAME", first)
        last_row.insert(2, "LAST_NAME", last)
        last_row.insert(3, "cbb_url", url)

        all_rows.append(last_row)
        summary.append({"PLAYER_ID": pid, "found": True, "url": url})

        # === Long polite delay ===
        sleep_time = 2.5 + random.uniform(1.0, 2.0)
        print(f"Sleeping {sleep_time:.1f}s...\n")
        time.sleep(sleep_time)

        if i % 12 == 0:
            print("Long break to avoid 429...")
            time.sleep(10)

    stats_df = pd.concat(all_rows, ignore_index=True) if all_rows else pd.DataFrame()
    summary_df = pd.DataFrame(summary)

    stats_df.to_csv(os.path.join(output_dir, "undrafted_college_stats.csv"), index=False)
    summary_df.to_csv(os.path.join(output_dir, "undrafted_summary.csv"), index=False)

    return stats_df, summary_df

# %%
import os
import re
import time
import random
import logging
from typing import Tuple, Optional

import requests
import pandas as pd

# ==========================
# Config
# ==========================

CBB_BASE = "https://www.sports-reference.com"

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
        "(KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
    )
}

# Configure logging (adjust level to DEBUG if you want more detail)
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
)


# ==========================
# HTTP Helpers
# ==========================

def safe_get(
    session: requests.Session,
    url: str,
    *,
    retries: int = 6,
    backoff: float = 2.0,
    timeout: int = 30,
) -> Optional[requests.Response]:
    """
    GET with exponential backoff, 429 handling, and 404 skip.

    Returns
    -------
    Response or None
        - Response: if 2xx or other status (that didn't trigger retry) succeeds
        - None: if 404 Not Found
    Raises
    ------
    last exception after `retries` attempts (for non-404 failures).
    """
    last_exc = None

    for i in range(retries):
        try:
            resp = session.get(url, headers=HEADERS, timeout=timeout)

            # Permanent: page does not exist → skip
            if resp.status_code == 404:
                logging.warning(f"404 Not Found: {url} — skipping this player.")
                return None

            # Rate limiting: 429 Too Many Requests → obey Retry-After or backoff
            if resp.status_code == 429:
                retry_after = resp.headers.get("Retry-After")
                try:
                    delay = int(retry_after)
                except Exception:
                    delay = backoff * (2 ** i) + random.uniform(0.5, 1.5)

                logging.warning(f"429 Too Many Requests at {url}, sleeping {delay:.1f}s")
                time.sleep(delay)
                continue

            # Raise for other HTTP errors (5xx, 4xx excluding 404/429)
            resp.raise_for_status()
            return resp

        except Exception as e:
            last_exc = e
            delay = backoff * (2 ** i) + random.uniform(0.5, 1.5)
            logging.warning(f"Error {e} while fetching {url}, sleeping {delay:.1f}s")
            time.sleep(delay)

    # Exhausted retries
    if last_exc is not None:
        raise last_exc
    return None


# ==========================
# URL Builder
# ==========================

def build_cbb_url(first: str, last: str) -> str:
    """
    Sports-Reference CBB uses `fn-ln-1.html` pattern.

    Example: LeBron James → lebron-james-1.html
    """
    fn = re.sub(r"[^a-z\s-]", "", first.lower()).replace(" ", "-")
    ln = re.sub(r"[^a-z\s-]", "", last.lower()).replace(" ", "-")
    return f"{CBB_BASE}/cbb/players/{fn}-{ln}-1.html"


# ==========================
# Resume Helpers
# ==========================

def _load_existing_data(output_dir: str):
    """
    If files already exist, load them so we can resume.
    Returns (stats_df, summary_df), where either can be empty DataFrame.
    """
    stats_path = os.path.join(output_dir, "undrafted_college_stats.csv")
    summary_path = os.path.join(output_dir, "undrafted_summary.csv")

    if os.path.exists(stats_path):
        stats_df = pd.read_csv(stats_path)
        logging.info(f"Loaded existing stats from {stats_path} (rows={len(stats_df)})")
    else:
        stats_df = pd.DataFrame()

    if os.path.exists(summary_path):
        summary_df = pd.read_csv(summary_path)
        logging.info(f"Loaded existing summary from {summary_path} (rows={len(summary_df)})")
    else:
        summary_df = pd.DataFrame()

    return stats_df, summary_df


def _save_data(
    stats_df: pd.DataFrame,
    summary_df: pd.DataFrame,
    output_dir: str,
) -> None:
    """Save both stats and summary to disk."""
    os.makedirs(output_dir, exist_ok=True)
    stats_path = os.path.join(output_dir, "undrafted_college_stats.csv")
    summary_path = os.path.join(output_dir, "undrafted_summary.csv")

    stats_df.to_csv(stats_path, index=False)
    summary_df.to_csv(summary_path, index=False)

    logging.info(
        f"Saved stats (rows={len(stats_df)}) to {stats_path} "
        f"and summary (rows={len(summary_df)}) to {summary_path}"
    )


# ==========================
# Main Scraper
# ==========================

def scrape_undrafted_players(
    df: pd.DataFrame,
    output_dir: str = "cbb_undrafted",
    *,
    save_every: int = 50,
    resume: bool = True,
    long_break_every: int = 12,
    long_break_seconds: int = 10,
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Scrape last-season college stats for undrafted players from Sports-Reference CBB.

    Parameters
    ----------
    df : DataFrame
        Must contain columns: PLAYER_ID, FIRST_NAME, LAST_NAME
    output_dir : str
        Directory to save CSVs.
    save_every : int
        Autosave after this many processed players (including skips).
    resume : bool
        If True, will load existing CSVs and skip players already marked found=True.
    long_break_every : int
        After this many players, take a longer sleep to avoid 429.
    long_break_seconds : int
        Duration of the long sleep.

    Returns
    -------
    (stats_df, summary_df) : Tuple[DataFrame, DataFrame]
        Final in-memory copies of stats and summary.
    """
    os.makedirs(output_dir, exist_ok=True)
    session = requests.Session()

    # Load existing data (for resume)
    existing_stats_df, existing_summary_df = _load_existing_data(output_dir)

    # Tracks new rows collected in this run
    new_stats_rows = []
    new_summary_rows = []

    # Determine which player_ids are already successfully scraped
    if resume and not existing_summary_df.empty and "PLAYER_ID" in existing_summary_df.columns:
        completed_ids = set(
            existing_summary_df.loc[
                existing_summary_df.get("found", False) == True,  # noqa: E712
                "PLAYER_ID",
            ].tolist()
        )
        logging.info(f"Resuming. Already completed players: {len(completed_ids)}")
    else:
        completed_ids = set()

    total_players = len(df)
    processed_since_save = 0

    for i, row in enumerate(df.itertuples(index=False), start=1):
        pid = row.PLAYER_ID
        first = row.FIRST_NAME
        last = row.LAST_NAME

        # Resume: skip if already scraped successfully
        if resume and pid in completed_ids:
            logging.info(f"[{i}/{total_players}] {first} {last} (PLAYER_ID={pid}) already scraped — skipping.")
            continue

        logging.info(f"[{i}/{total_players}] Scraping {first} {last} (PLAYER_ID={pid})")

        url = build_cbb_url(first, last)

        try:
            resp = safe_get(session, url)
        except Exception as e:
            logging.error(f"Failed for {first} {last} ({pid}) at {url}: {e}")
            new_summary_rows.append(
                {
                    "PLAYER_ID": pid,
                    "FIRST_NAME": first,
                    "LAST_NAME": last,
                    "found": False,
                    "url": url,
                    "error": str(e),
                }
            )
            processed_since_save += 1
            # small polite delay even on error
            time.sleep(1.0 + random.uniform(0.5, 1.0))
            # periodic save
            if processed_since_save >= save_every:
                logging.info("Autosaving due to processed_since_save >= save_every (error path).")
                existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
                    existing_stats_df,
                    existing_summary_df,
                    new_stats_rows,
                    new_summary_rows,
                    output_dir,
                )
                new_stats_rows, new_summary_rows = [], []
            continue

        # 404 (None) → skip
        if resp is None:
            new_summary_rows.append(
                {
                    "PLAYER_ID": pid,
                    "FIRST_NAME": first,
                    "LAST_NAME": last,
                    "found": False,
                    "url": None,
                    "error": "404 Not Found",
                }
            )
            logging.info(f"No page for {first} {last} ({pid}), recorded as not found.")
            processed_since_save += 1
            time.sleep(1.0 + random.uniform(0.5, 1.0))
            if processed_since_save >= save_every:
                logging.info("Autosaving due to processed_since_save >= save_every (404 path).")
                existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
                    existing_stats_df,
                    existing_summary_df,
                    new_stats_rows,
                    new_summary_rows,
                    output_dir,
                )
                new_stats_rows, new_summary_rows = [], []
            continue

        # Parse HTML tables
        try:
            tables = pd.read_html(resp.text, flavor="lxml")
        except ValueError as e:
            logging.warning(f"No tables found for {first} {last} ({pid}) at {url}: {e}")
            new_summary_rows.append(
                {
                    "PLAYER_ID": pid,
                    "FIRST_NAME": first,
                    "LAST_NAME": last,
                    "found": False,
                    "url": url,
                    "error": "no HTML tables",
                }
            )
            processed_since_save += 1
            time.sleep(1.0 + random.uniform(0.5, 1.0))
            if processed_since_save >= save_every:
                logging.info("Autosaving due to processed_since_save >= save_every (no-table path).")
                existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
                    existing_stats_df,
                    existing_summary_df,
                    new_stats_rows,
                    new_summary_rows,
                    output_dir,
                )
                new_stats_rows, new_summary_rows = [], []
            continue

        # Find season table (table containing "Season" column)
        season_table = None
        for t in tables:
            if "Season" in t.columns:
                season_table = t
                break

        if season_table is None:
            logging.warning(f"No season table found for {first} {last} ({pid}) at {url}")
            new_summary_rows.append(
                {
                    "PLAYER_ID": pid,
                    "FIRST_NAME": first,
                    "LAST_NAME": last,
                    "found": False,
                    "url": url,
                    "error": "no Season table",
                }
            )
            processed_since_save += 1
            time.sleep(1.0 + random.uniform(0.5, 1.0))
            if processed_since_save >= save_every:
                logging.info("Autosaving due to processed_since_save >= save_every (no-season-table path).")
                existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
                    existing_stats_df,
                    existing_summary_df,
                    new_stats_rows,
                    new_summary_rows,
                    output_dir,
                )
                new_stats_rows, new_summary_rows = [], []
            continue

        # Clean season table: drop header repeat rows, 'Career', NaNs
        season_table = season_table.copy()
        season_table = season_table[season_table["Season"].notna()]
        season_table = season_table[~season_table["Season"].isin(["Season", "Career"])]

        if season_table.empty:
            logging.warning(f"No usable rows in season table for {first} {last} ({pid}) at {url}")
            new_summary_rows.append(
                {
                    "PLAYER_ID": pid,
                    "FIRST_NAME": first,
                    "LAST_NAME": last,
                    "found": False,
                    "url": url,
                    "error": "empty season table",
                }
            )
            processed_since_save += 1
            time.sleep(1.0 + random.uniform(0.5, 1.0))
            if processed_since_save >= save_every:
                logging.info("Autosaving due to processed_since_save >= save_every (empty-season path).")
                existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
                    existing_stats_df,
                    existing_summary_df,
                    new_stats_rows,
                    new_summary_rows,
                    output_dir,
                )
                new_stats_rows, new_summary_rows = [], []
            continue

        # Take last row (last season)
        last_row = season_table.tail(1).copy()
        last_row.insert(0, "PLAYER_ID", pid)
        last_row.insert(1, "FIRST_NAME", first)
        last_row.insert(2, "LAST_NAME", last)
        last_row.insert(3, "cbb_url", url)

        new_stats_rows.append(last_row)
        new_summary_rows.append(
            {
                "PLAYER_ID": pid,
                "FIRST_NAME": first,
                "LAST_NAME": last,
                "found": True,
                "url": url,
                "error": "",
            }
        )

        # Polite delay between requests
        sleep_time = 2.5 + random.uniform(1.0, 2.0)
        logging.info(f"Sleeping {sleep_time:.1f}s after {first} {last}")
        time.sleep(sleep_time)

        # Longer break every N players
        if long_break_every > 0 and i % long_break_every == 0:
            logging.info(f"Long break after {i} players to avoid 429...")
            time.sleep(long_break_seconds)

        processed_since_save += 1

        # Autosave periodically
        if processed_since_save >= save_every:
            logging.info("Autosaving due to processed_since_save >= save_every (normal path).")
            existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
                existing_stats_df,
                existing_summary_df,
                new_stats_rows,
                new_summary_rows,
                output_dir,
            )
            new_stats_rows, new_summary_rows = [], []

    # Final save for any remaining rows
    if new_stats_rows or new_summary_rows:
        logging.info("Final save of remaining rows at end of run.")
        existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
            existing_stats_df,
            existing_summary_df,
            new_stats_rows,
            new_summary_rows,
            output_dir,
        )

    return existing_stats_df, existing_summary_df


def _merge_and_save(
    existing_stats_df: pd.DataFrame,
    existing_summary_df: pd.DataFrame,
    new_stats_rows: list,
    new_summary_rows: list,
    output_dir: str,
):
    """
    Merge new rows into existing DataFrames and save to disk.
    Returns updated stats_df, summary_df, and resets processed_since_save.
    """
    if new_stats_rows:
        new_stats_df = pd.concat(new_stats_rows, ignore_index=True)
        if existing_stats_df.empty:
            combined_stats_df = new_stats_df
        else:
            combined_stats_df = pd.concat(
                [existing_stats_df, new_stats_df],
                ignore_index=True,
            ).drop_duplicates(subset=["PLAYER_ID", "Season"], keep="last")
    else:
        combined_stats_df = existing_stats_df

    if new_summary_rows:
        new_summary_df = pd.DataFrame(new_summary_rows)
        if existing_summary_df.empty:
            combined_summary_df = new_summary_df
        else:
            combined_summary_df = pd.concat(
                [existing_summary_df, new_summary_df],
                ignore_index=True,
            ).drop_duplicates(subset=["PLAYER_ID"], keep="last")
    else:
        combined_summary_df = existing_summary_df

    _save_data(combined_stats_df, combined_summary_df, output_dir)

    # Reset processed counter
    processed_since_save = 0
    return combined_stats_df, combined_summary_df, processed_since_save


# ==========================
# Optional CLI Example
# ==========================

if __name__ == "__main__":
    """
    Example usage:

    Suppose you already have a DataFrame `df_players` with columns:
        - PLAYER_ID
        - FIRST_NAME
        - LAST_NAME

    You might load it from CSV like this:
        df_players = pd.read_csv("undrafted_players.csv")

    Then run:
        scrape_undrafted_players(df_players, output_dir="cbb_undrafted")
    """
    print("This module is intended to be imported and used from another script.")
# Out:
# This module is intended to be imported and used from another script.

# %%
college_stats_undrafted, summary = scrape_undrafted_players(
    undrafted_combine_players,
    output_dir="ndrafted"
)
# Out:
# 2025-12-09 15:09:25,044 [INFO] [1/705] Scraping Justin Love (PLAYER_ID=2090)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:09:25,126 [INFO] Sleeping 4.2s after Justin Love
# 2025-12-09 15:09:29,292 [INFO] [2/705] Scraping Brandon Kurtz (PLAYER_ID=12144)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:09:29,342 [INFO] Sleeping 4.0s after Brandon Kurtz
# 2025-12-09 15:09:33,305 [INFO] [3/705] Scraping Kenyon Jones (PLAYER_ID=12143)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:09:33,355 [INFO] Sleeping 3.6s after Kenyon Jones
# 2025-12-09 15:09:36,932 [INFO] [4/705] Scraping Nate Johnson (PLAYER_ID=12142)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:09:36,993 [INFO] Sleeping 3.7s after Nate Johnson
# 2025-12-09 15:09:40,686 [INFO] [5/705] Scraping Jacob Jaacks (PLAYER_ID=12141)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:09:40,737 [INFO] Sleeping 4.0s after Jacob Jaacks
# 2025-12-09 15:09:44,767 [INFO] [6/705] Scraping Jimmie Hunter (PLAYER_ID=2111)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:09:44,824 [INFO] Sleeping 3.8s after Jimmie Hunter
# 2025-12-09 15:09:48,652 [INFO] [7/705] Scraping Shaheen Holloway (PLAYER_ID=12140)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:09:48,698 [INFO] Sleeping 4.0s after Shaheen Holloway
# 2025-12-09 15:09:52,711 [INFO] [8/705] Scraping Michael Hermon (PLAYER_ID=12139)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:09:52,758 [INFO] Sleeping 3.5s after Michael Hermon
# 2025-12-09 15:09:56,300 [INFO] [9/705] Scraping Johnny Hemsley (PLAYER_ID=12138)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:09:56,357 [INFO] Sleeping 3.7s after Johnny Hemsley
# 2025-12-09 15:10:00,103 [INFO] [10/705] Scraping Ron Hale (PLAYER_ID=2110)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:10:00,151 [INFO] Sleeping 4.1s after Ron Hale
# 2025-12-09 15:10:04,276 [INFO] [11/705] Scraping A.J. Granger (PLAYER_ID=12137)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:10:04,349 [INFO] Sleeping 4.3s after A.J. Granger
# 2025-12-09 15:10:08,684 [INFO] [12/705] Scraping Marcus Goree (PLAYER_ID=12136)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:10:08,740 [INFO] Sleeping 4.3s after Marcus Goree
# 2025-12-09 15:10:13,086 [INFO] Long break after 12 players to avoid 429...
# 2025-12-09 15:10:23,092 [INFO] [13/705] Scraping Ceedric Goodwyn (PLAYER_ID=12135)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:10:23,141 [INFO] Sleeping 3.7s after Ceedric Goodwyn
# 2025-12-09 15:10:26,876 [INFO] [14/705] Scraping Eddie Gill (PLAYER_ID=2109)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:10:26,934 [INFO] Sleeping 4.1s after Eddie Gill
# 2025-12-09 15:10:31,024 [INFO] [15/705] Scraping Vassil Evtimov (PLAYER_ID=12018)
# 2025-12-09 15:10:31,076 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/vassil-evtimov-1.html — skipping this player.
# 2025-12-09 15:10:31,077 [INFO] No page for Vassil Evtimov (12018), recorded as not found.
# 2025-12-09 15:10:33,043 [INFO] [16/705] Scraping Gabe Muoneke (PLAYER_ID=2508)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:10:33,468 [INFO] Sleeping 3.6s after Gabe Muoneke
# 2025-12-09 15:10:37,035 [INFO] [17/705] Scraping Schea Cotton (PLAYER_ID=12134)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:10:37,125 [INFO] Sleeping 4.0s after Schea Cotton
# 2025-12-09 15:10:41,112 [INFO] [18/705] Scraping Jameel Watkins (PLAYER_ID=12030)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:10:41,432 [INFO] Sleeping 3.6s after Jameel Watkins
# 2025-12-09 15:10:45,036 [INFO] [19/705] Scraping Jaquay Walls (PLAYER_ID=12029)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:10:45,448 [INFO] Sleeping 4.1s after Jaquay Walls
# 2025-12-09 15:10:49,567 [INFO] [20/705] Scraping Bootsy Thornton (PLAYER_ID=12028)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:10:49,908 [INFO] Sleeping 4.4s after Bootsy Thornton
# 2025-12-09 15:10:54,307 [INFO] [21/705] Scraping Jarrett Stephens (PLAYER_ID=12027)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:10:54,664 [INFO] Sleeping 3.7s after Jarrett Stephens
# 2025-12-09 15:10:58,331 [INFO] [22/705] Scraping Nick Sheppard (PLAYER_ID=12026)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:10:58,962 [INFO] Sleeping 4.0s after Nick Sheppard
# 2025-12-09 15:11:03,005 [INFO] [23/705] Scraping Karim Shabazz (PLAYER_ID=12025)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:11:03,101 [INFO] Sleeping 3.6s after Karim Shabazz
# 2025-12-09 15:11:06,724 [INFO] [24/705] Scraping Alex Scales (PLAYER_ID=2637)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:11:07,050 [INFO] Sleeping 3.7s after Alex Scales
# 2025-12-09 15:11:10,716 [INFO] Long break after 24 players to avoid 429...
# 2025-12-09 15:11:20,722 [INFO] [25/705] Scraping Matt Santangelo (PLAYER_ID=12024)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:11:21,002 [INFO] Sleeping 4.1s after Matt Santangelo
# 2025-12-09 15:11:25,082 [INFO] [26/705] Scraping Brian Montonati (PLAYER_ID=12145)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:11:25,157 [INFO] Sleeping 3.7s after Brian Montonati
# 2025-12-09 15:11:28,858 [INFO] [27/705] Scraping Pepe Sanchez (PLAYER_ID=12023)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:11:29,275 [INFO] Sleeping 3.7s after Pepe Sanchez
# 2025-12-09 15:11:33,000 [INFO] [28/705] Scraping Terrance Roberson (PLAYER_ID=2121)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:11:33,309 [INFO] Sleeping 3.6s after Terrance Roberson
# 2025-12-09 15:11:36,869 [INFO] [29/705] Scraping Aubrey Reese (PLAYER_ID=12021)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:11:37,261 [INFO] Sleeping 3.8s after Aubrey Reese
# 2025-12-09 15:11:41,071 [INFO] [30/705] Scraping Damon Reed (PLAYER_ID=12149)
# 2025-12-09 15:11:41,127 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/damon-reed-1.html — skipping this player.
# 2025-12-09 15:11:41,127 [INFO] No page for Damon Reed (12149), recorded as not found.
# 2025-12-09 15:11:42,920 [INFO] [31/705] Scraping Reed Rawlings (PLAYER_ID=12148)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:11:43,230 [INFO] Sleeping 3.7s after Reed Rawlings
# 2025-12-09 15:11:46,955 [INFO] [32/705] Scraping Matthew Nielsen (PLAYER_ID=12147)
# 2025-12-09 15:11:47,026 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/matthew-nielsen-1.html — skipping this player.
# 2025-12-09 15:11:47,027 [INFO] No page for Matthew Nielsen (12147), recorded as not found.
# 2025-12-09 15:11:48,559 [INFO] [33/705] Scraping Ndongo N'diaye (PLAYER_ID=12146)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:11:48,864 [INFO] Sleeping 3.6s after Ndongo N'diaye
# 2025-12-09 15:11:52,483 [INFO] [34/705] Scraping Julius Doc Robinson (PLAYER_ID=12022)
# 2025-12-09 15:11:52,531 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/julius-doc-robinson-1.html — skipping this player.
# 2025-12-09 15:11:52,532 [INFO] No page for Julius Doc Robinson (12022), recorded as not found.
# 2025-12-09 15:11:54,047 [INFO] [35/705] Scraping Caswell Cyrus (PLAYER_ID=12017)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:11:54,473 [INFO] Sleeping 3.7s after Caswell Cyrus
# 2025-12-09 15:11:58,132 [INFO] [36/705] Scraping Ed Cota (PLAYER_ID=12133)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:11:58,385 [INFO] Sleeping 3.6s after Ed Cota
# 2025-12-09 15:12:02,021 [INFO] Long break after 36 players to avoid 429...
# 2025-12-09 15:12:12,027 [INFO] [37/705] Scraping Eric Coley (PLAYER_ID=12132)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:12:12,485 [INFO] Sleeping 4.3s after Eric Coley
# 2025-12-09 15:12:16,831 [INFO] [38/705] Scraping Mario Bland (PLAYER_ID=12131)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:12:17,301 [INFO] Sleeping 4.3s after Mario Bland
# 2025-12-09 15:12:21,598 [INFO] [39/705] Scraping Lamont Barnes (PLAYER_ID=12020)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:12:22,009 [INFO] Sleeping 3.9s after Lamont Barnes
# 2025-12-09 15:12:25,955 [INFO] [40/705] Scraping Harold Arceneaux (PLAYER_ID=12019)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:12:26,249 [INFO] Sleeping 3.9s after Harold Arceneaux
# 2025-12-09 15:12:30,115 [INFO] [41/705] Scraping Malik Allen (PLAYER_ID=2124)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:12:30,472 [INFO] Sleeping 3.7s after Malik Allen
# 2025-12-09 15:12:34,202 [INFO] [42/705] Scraping Jason Gardner (PLAYER_ID=-1)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:12:34,611 [INFO] Sleeping 4.3s after Jason Gardner
# 2025-12-09 15:12:38,883 [INFO] [43/705] Scraping Michael Hicks (PLAYER_ID=12154)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:12:39,215 [INFO] Sleeping 3.8s after Michael Hicks
# 2025-12-09 15:12:43,049 [INFO] [44/705] Scraping Andre Hutson (PLAYER_ID=12155)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:12:43,131 [INFO] Sleeping 4.1s after Andre Hutson
# 2025-12-09 15:12:47,216 [INFO] [45/705] Scraping Nate James (PLAYER_ID=12156)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:12:47,305 [INFO] Sleeping 3.8s after Nate James
# 2025-12-09 15:12:51,083 [INFO] [46/705] Scraping Darren Kelly (PLAYER_ID=12158)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:12:51,605 [INFO] Sleeping 4.0s after Darren Kelly
# 2025-12-09 15:12:55,656 [INFO] [47/705] Scraping Darrell Johns (PLAYER_ID=12157)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:12:55,726 [INFO] Sleeping 3.5s after Darrell Johns
# 2025-12-09 15:12:59,237 [INFO] [48/705] Scraping Horace Jenkins (PLAYER_ID=2798)
# 2025-12-09 15:12:59,285 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/horace-jenkins-1.html — skipping this player.
# 2025-12-09 15:12:59,286 [INFO] No page for Horace Jenkins (2798), recorded as not found.
# 2025-12-09 15:13:00,793 [INFO] [49/705] Scraping Charles Hathaway (PLAYER_ID=12153)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:13:00,864 [INFO] Sleeping 4.5s after Charles Hathaway
# 2025-12-09 15:13:05,324 [INFO] [50/705] Scraping Adam Allenspach (PLAYER_ID=12033)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:13:05,736 [INFO] Sleeping 4.1s after Adam Allenspach
# 2025-12-09 15:13:09,856 [INFO] Autosaving due to processed_since_save >= save_every (normal path).
# 2025-12-09 15:13:09,873 [INFO] Saved stats (rows=45) to cbb_undrafted/undrafted_college_stats.csv and summary (rows=50) to cbb_undrafted/undrafted_summary.csv
# 2025-12-09 15:13:09,874 [INFO] [51/705] Scraping Kenny Gregory (PLAYER_ID=12152)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:13:10,243 [INFO] Sleeping 3.6s after Kenny Gregory
# 2025-12-09 15:13:13,887 [INFO] [52/705] Scraping Cookie Belcher (PLAYER_ID=12034)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:13:14,046 [INFO] Sleeping 4.1s after Cookie Belcher
# 2025-12-09 15:13:18,175 [INFO] [53/705] Scraping Charlie Bell (PLAYER_ID=2294)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:13:18,537 [INFO] Sleeping 4.2s after Charlie Bell
# 2025-12-09 15:13:22,738 [INFO] [54/705] Scraping Calvin Bowman (PLAYER_ID=12035)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:13:23,045 [INFO] Sleeping 3.7s after Calvin Bowman
# 2025-12-09 15:13:26,733 [INFO] [55/705] Scraping Zach Marbury (PLAYER_ID=12159)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:13:27,087 [INFO] Sleeping 3.8s after Zach Marbury
# 2025-12-09 15:13:30,907 [INFO] [56/705] Scraping Troy Ostler (PLAYER_ID=12162)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:13:31,473 [INFO] Sleeping 4.2s after Troy Ostler
# 2025-12-09 15:13:35,682 [INFO] [57/705] Scraping DeMarcus Minor (PLAYER_ID=12161)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:13:36,113 [INFO] Sleeping 4.1s after DeMarcus Minor
# 2025-12-09 15:13:40,193 [INFO] [58/705] Scraping Michael Wright (PLAYER_ID=12041)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:13:40,704 [INFO] Sleeping 4.2s after Michael Wright
# 2025-12-09 15:13:44,917 [INFO] [59/705] Scraping Brent Wright (PLAYER_ID=12040)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:13:45,204 [INFO] Sleeping 3.8s after Brent Wright
# 2025-12-09 15:13:48,981 [INFO] [60/705] Scraping Souleymane Wane (PLAYER_ID=12172)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:13:49,052 [INFO] Sleeping 4.1s after Souleymane Wane
# 2025-12-09 15:13:53,193 [INFO] Long break after 60 players to avoid 429...
# 2025-12-09 15:14:03,199 [INFO] [61/705] Scraping Jerry Green (PLAYER_ID=12151)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:14:03,654 [INFO] Sleeping 3.7s after Jerry Green
# 2025-12-09 15:14:07,355 [INFO] [62/705] Scraping Damone Thornton (PLAYER_ID=12170)
# 2025-12-09 15:14:07,408 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/damone-thornton-1.html — skipping this player.
# 2025-12-09 15:14:07,408 [INFO] No page for Damone Thornton (12170), recorded as not found.
# 2025-12-09 15:14:08,926 [INFO] [63/705] Scraping Greg Stevenson (PLAYER_ID=12169)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:14:09,330 [INFO] Sleeping 3.7s after Greg Stevenson
# 2025-12-09 15:14:13,049 [INFO] [64/705] Scraping Lee Scruggs (PLAYER_ID=12168)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:14:13,243 [INFO] Sleeping 4.1s after Lee Scruggs
# 2025-12-09 15:14:17,328 [INFO] [65/705] Scraping Kenny Satterfield (PLAYER_ID=12167)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:14:17,562 [INFO] Sleeping 4.0s after Kenny Satterfield
# 2025-12-09 15:14:21,532 [INFO] [66/705] Scraping Norman Richardson (PLAYER_ID=2369)
# 2025-12-09 15:14:21,587 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/norman-richardson-1.html — skipping this player.
# 2025-12-09 15:14:21,587 [INFO] No page for Norman Richardson (2369), recorded as not found.
# 2025-12-09 15:14:23,504 [INFO] [67/705] Scraping Martin Rancik (PLAYER_ID=12166)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:14:23,693 [INFO] Sleeping 4.3s after Martin Rancik
# 2025-12-09 15:14:28,035 [INFO] [68/705] Scraping Demetrius Porter (PLAYER_ID=12165)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:14:28,295 [INFO] Sleeping 4.4s after Demetrius Porter
# 2025-12-09 15:14:32,661 [INFO] [69/705] Scraping Rashad Phillips (PLAYER_ID=12164)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:14:32,756 [INFO] Sleeping 4.0s after Rashad Phillips
# 2025-12-09 15:14:36,764 [INFO] [70/705] Scraping Lazaros Papadopoulos (PLAYER_ID=40046)
# 2025-12-09 15:14:36,850 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/lazaros-papadopoulos-1.html — skipping this player.
# 2025-12-09 15:14:36,851 [INFO] No page for Lazaros Papadopoulos (40046), recorded as not found.
# 2025-12-09 15:14:38,693 [INFO] [71/705] Scraping Jamario Moon (PLAYER_ID=200081)
# 2025-12-09 15:14:38,747 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/jamario-moon-1.html — skipping this player.
# 2025-12-09 15:14:38,747 [INFO] No page for Jamario Moon (200081), recorded as not found.
# 2025-12-09 15:14:40,726 [INFO] [72/705] Scraping Mike Mardesich (PLAYER_ID=12160)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:14:41,173 [INFO] Sleeping 4.2s after Mike Mardesich
# 2025-12-09 15:14:45,345 [INFO] Long break after 72 players to avoid 429...
# 2025-12-09 15:14:55,352 [INFO] [73/705] Scraping Tory Walker (PLAYER_ID=12171)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:14:55,935 [INFO] Sleeping 4.0s after Tory Walker
# 2025-12-09 15:14:59,924 [INFO] [74/705] Scraping SirValiant Brown (PLAYER_ID=12031)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:15:00,262 [INFO] Sleeping 4.1s after SirValiant Brown
# 2025-12-09 15:15:04,358 [INFO] [75/705] Scraping Ryan Carroll (PLAYER_ID=12032)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:15:04,647 [INFO] Sleeping 4.2s after Ryan Carroll
# 2025-12-09 15:15:08,806 [INFO] [76/705] Scraping Gyasi Cline-Heard (PLAYER_ID=12036)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:15:09,093 [INFO] Sleeping 3.8s after Gyasi Cline-Heard
# 2025-12-09 15:15:12,872 [INFO] [77/705] Scraping Tate Decker (PLAYER_ID=12037)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:15:13,533 [INFO] Sleeping 4.1s after Tate Decker
# 2025-12-09 15:15:17,629 [INFO] [78/705] Scraping Maurice Evans (PLAYER_ID=2230)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:15:17,840 [INFO] Sleeping 4.5s after Maurice Evans
# 2025-12-09 15:15:22,304 [INFO] [79/705] Scraping Anthony Evans (PLAYER_ID=12039)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:15:22,941 [INFO] Sleeping 3.6s after Anthony Evans
# 2025-12-09 15:15:26,562 [INFO] [80/705] Scraping Benjamin Eze (PLAYER_ID=12150)
# 2025-12-09 15:15:26,618 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/benjamin-eze-1.html — skipping this player.
# 2025-12-09 15:15:26,621 [INFO] No page for Benjamin Eze (12150), recorded as not found.
# 2025-12-09 15:15:28,153 [INFO] [81/705] Scraping Kimani Ffriend (PLAYER_ID=2386)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:15:28,464 [INFO] Sleeping 3.7s after Kimani Ffriend
# 2025-12-09 15:15:32,131 [INFO] [82/705] Scraping Robb Dryden (PLAYER_ID=12038)
# 2025-12-09 15:15:32,190 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/robb-dryden-1.html — skipping this player.
# 2025-12-09 15:15:32,191 [INFO] No page for Robb Dryden (12038), recorded as not found.
# 2025-12-09 15:15:33,715 [INFO] [83/705] Scraping Andy Ellis (PLAYER_ID=12046)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:15:34,087 [INFO] Sleeping 3.9s after Andy Ellis
# 2025-12-09 15:15:38,012 [INFO] [84/705] Scraping Teddy Dupay (PLAYER_ID=12045)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:15:38,476 [INFO] Sleeping 3.9s after Teddy Dupay
# 2025-12-09 15:15:42,389 [INFO] Long break after 84 players to avoid 429...
# 2025-12-09 15:15:52,395 [INFO] [85/705] Scraping Craig Dawson (PLAYER_ID=12044)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:15:52,652 [INFO] Sleeping 3.7s after Craig Dawson
# 2025-12-09 15:15:56,338 [INFO] [86/705] Scraping Reggie Evans (PLAYER_ID=2501)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:15:56,615 [INFO] Sleeping 4.0s after Reggie Evans
# 2025-12-09 15:16:00,591 [INFO] [87/705] Scraping Lenny Cooke (PLAYER_ID=12043)
# 2025-12-09 15:16:00,645 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/lenny-cooke-1.html — skipping this player.
# 2025-12-09 15:16:00,647 [INFO] No page for Lenny Cooke (12043), recorded as not found.
# 2025-12-09 15:16:02,310 [INFO] [88/705] Scraping David Graves (PLAYER_ID=12066)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:16:02,393 [INFO] Sleeping 3.7s after David Graves
# 2025-12-09 15:16:06,052 [INFO] [89/705] Scraping Lynn Greer (PLAYER_ID=2696)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:16:06,399 [INFO] Sleeping 4.2s after Lynn Greer
# 2025-12-09 15:16:10,626 [INFO] [90/705] Scraping Rod Grizzard (PLAYER_ID=12067)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:16:10,966 [INFO] Sleeping 3.9s after Rod Grizzard
# 2025-12-09 15:16:14,897 [INFO] [91/705] Scraping Anthony Grundy (PLAYER_ID=101219)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:16:15,236 [INFO] Sleeping 4.2s after Anthony Grundy
# 2025-12-09 15:16:19,431 [INFO] [92/705] Scraping Peter Fehse (PLAYER_ID=12047)
# 2025-12-09 15:16:19,493 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/peter-fehse-1.html — skipping this player.
# 2025-12-09 15:16:19,495 [INFO] No page for Peter Fehse (12047), recorded as not found.
# 2025-12-09 15:16:21,024 [INFO] [93/705] Scraping Chris Christoffersen (PLAYER_ID=12042)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:16:21,528 [INFO] Sleeping 4.3s after Chris Christoffersen
# 2025-12-09 15:16:25,848 [INFO] [94/705] Scraping Lee Benson (PLAYER_ID=12287)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:16:26,137 [INFO] Sleeping 3.9s after Lee Benson
# 2025-12-09 15:16:29,996 [INFO] [95/705] Scraping Chris Burgess (PLAYER_ID=12290)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:16:30,089 [INFO] Sleeping 3.5s after Chris Burgess
# 2025-12-09 15:16:33,601 [INFO] [96/705] Scraping Sylvere Bryan (PLAYER_ID=12289)
# 2025-12-09 15:16:33,656 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/sylvere-bryan-1.html — skipping this player.
# 2025-12-09 15:16:33,658 [INFO] No page for Sylvere Bryan (12289), recorded as not found.
# 2025-12-09 15:16:35,484 [INFO] [97/705] Scraping Brian Brown (PLAYER_ID=12288)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:16:35,804 [INFO] Sleeping 3.8s after Brian Brown
# 2025-12-09 15:16:39,580 [INFO] [98/705] Scraping J.R. Bremer (PLAYER_ID=2452)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:16:39,650 [INFO] Sleeping 4.4s after J.R. Bremer
# 2025-12-09 15:16:44,023 [INFO] [99/705] Scraping Maurice Baker (PLAYER_ID=2486)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:16:44,105 [INFO] Sleeping 3.9s after Maurice Baker
# 2025-12-09 15:16:48,009 [INFO] [100/705] Scraping Mire Chatman (PLAYER_ID=12291)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:16:48,086 [INFO] Sleeping 4.2s after Mire Chatman
# 2025-12-09 15:16:52,252 [INFO] Autosaving due to processed_since_save >= save_every (normal path).
# 2025-12-09 15:16:52,275 [INFO] Saved stats (rows=86) to cbb_undrafted/undrafted_college_stats.csv and summary (rows=100) to cbb_undrafted/undrafted_summary.csv
# 2025-12-09 15:16:52,275 [INFO] [101/705] Scraping Lubos Barton (PLAYER_ID=12286)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:16:52,635 [INFO] Sleeping 4.0s after Lubos Barton
# 2025-12-09 15:16:56,612 [INFO] [102/705] Scraping Damon Hancock (PLAYER_ID=12068)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:16:56,958 [INFO] Sleeping 3.9s after Damon Hancock
# 2025-12-09 15:17:00,897 [INFO] [103/705] Scraping Udonis Haslem (PLAYER_ID=2617)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:17:00,982 [INFO] Sleeping 3.6s after Udonis Haslem
# 2025-12-09 15:17:04,593 [INFO] [104/705] Scraping George Williams (PLAYER_ID=2465)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:17:04,918 [INFO] Sleeping 4.4s after George Williams
# 2025-12-09 15:17:09,330 [INFO] [105/705] Scraping Jobey Thomas (PLAYER_ID=12297)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:17:09,756 [INFO] Sleeping 3.6s after Jobey Thomas
# 2025-12-09 15:17:13,390 [INFO] [106/705] Scraping Preston Shumpert (PLAYER_ID=12065)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:17:13,751 [INFO] Sleeping 4.0s after Preston Shumpert
# 2025-12-09 15:17:17,712 [INFO] [107/705] Scraping Julian Sensley (PLAYER_ID=201324)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:17:17,797 [INFO] Sleeping 4.0s after Julian Sensley
# 2025-12-09 15:17:21,756 [INFO] [108/705] Scraping Predrag Savovic (PLAYER_ID=2453)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:17:22,004 [INFO] Sleeping 4.5s after Predrag Savovic
# 2025-12-09 15:17:26,494 [INFO] Long break after 108 players to avoid 429...
# 2025-12-09 15:17:36,501 [INFO] [109/705] Scraping Brooks Sales (PLAYER_ID=12063)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 15:17:36,612 [INFO] Sleeping 3.9s after Brooks Sales
# ...
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:00:53,041 [INFO] Sleeping 4.4s after Jesse Edwards
# 2025-12-09 16:00:57,431 [INFO] [670/705] Scraping Boogie Ellis (PLAYER_ID=1642407)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:00:57,543 [INFO] Sleeping 4.4s after Boogie Ellis
# 2025-12-09 16:01:01,906 [INFO] [671/705] Scraping N'Faly Dante (PLAYER_ID=1642368)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:01:02,244 [INFO] Sleeping 3.6s after N'Faly Dante
# 2025-12-09 16:01:05,837 [INFO] [672/705] Scraping Isaac Jones (PLAYER_ID=1642403)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:01:06,075 [INFO] Sleeping 4.1s after Isaac Jones
# 2025-12-09 16:01:10,167 [INFO] Long break after 672 players to avoid 429...
# 2025-12-09 16:01:20,173 [INFO] [673/705] Scraping David Jones (PLAYER_ID=1642357)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:01:20,407 [INFO] Sleeping 3.5s after David Jones
# 2025-12-09 16:01:23,924 [INFO] [674/705] Scraping Keshad Johnson (PLAYER_ID=1642352)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:01:24,035 [INFO] Sleeping 3.5s after Keshad Johnson
# 2025-12-09 16:01:27,539 [INFO] [675/705] Scraping Coleman Hawkins (PLAYER_ID=1641746)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:01:27,601 [INFO] Sleeping 4.5s after Coleman Hawkins
# 2025-12-09 16:01:32,104 [INFO] [676/705] Scraping PJ Hall (PLAYER_ID=1641790)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:01:32,207 [INFO] Sleeping 4.4s after PJ Hall
# 2025-12-09 16:01:36,642 [INFO] [677/705] Scraping Tyon Grant-Foster (PLAYER_ID=1642360)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:01:36,736 [INFO] Sleeping 3.7s after Tyon Grant-Foster
# 2025-12-09 16:01:40,392 [INFO] [678/705] Scraping Trentyn Flowers (PLAYER_ID=1642280)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:01:40,751 [WARNING] No tables found for Trentyn Flowers (1642280) at https://www.sports-reference.com/cbb/players/trentyn-flowers-1.html: No tables found matching regex '.+'
# 2025-12-09 16:01:42,700 [INFO] [679/705] Scraping Ben Henshall (PLAYER_ID=1642916)
# 2025-12-09 16:01:42,769 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/ben-henshall-1.html — skipping this player.
# 2025-12-09 16:01:42,770 [INFO] No page for Ben Henshall (1642916), recorded as not found.
# 2025-12-09 16:01:44,412 [INFO] [680/705] Scraping Karter Knox (PLAYER_ID=1642909)
# 2025-12-09 16:01:44,489 [INFO] Sleeping 4.0s after Karter Knox
# 2025-12-09 16:01:48,524 [INFO] [681/705] Scraping Yaxel Lendeborg (PLAYER_ID=1642865)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:01:48,608 [INFO] Sleeping 4.1s after Yaxel Lendeborg
# 2025-12-09 16:01:52,711 [INFO] [682/705] Scraping RJ Luis Jr. (PLAYER_ID=1642961)
# 2025-12-09 16:01:52,788 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/rj-luis-jr-1.html — skipping this player.
# 2025-12-09 16:01:52,789 [INFO] No page for RJ Luis Jr. (1642961), recorded as not found.
# 2025-12-09 16:01:54,476 [INFO] [683/705] Scraping PJ Haggerty (PLAYER_ID=1642919)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:01:54,594 [INFO] Sleeping 4.4s after PJ Haggerty
# 2025-12-09 16:01:58,995 [INFO] [684/705] Scraping Mackenzie Mgbako (PLAYER_ID=1642944)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:01:59,240 [WARNING] No tables found for Mackenzie Mgbako (1642944) at https://www.sports-reference.com/cbb/players/mackenzie-mgbako-1.html: No tables found matching regex '.+'
# 2025-12-09 16:02:01,160 [INFO] [685/705] Scraping Miles Byrd (PLAYER_ID=1642891)
# 2025-12-09 16:02:01,236 [INFO] Sleeping 3.6s after Miles Byrd
# 2025-12-09 16:02:04,813 [INFO] [686/705] Scraping Vladislav Goldin (PLAYER_ID=1642884)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:02:04,927 [INFO] Sleeping 4.4s after Vladislav Goldin
# 2025-12-09 16:02:09,342 [INFO] [687/705] Scraping Alex Condon (PLAYER_ID=1642960)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:02:09,447 [INFO] Sleeping 3.6s after Alex Condon
# 2025-12-09 16:02:13,095 [INFO] [688/705] Scraping Eric Dixon (PLAYER_ID=1642915)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:02:13,172 [INFO] Sleeping 3.9s after Eric Dixon
# 2025-12-09 16:02:17,110 [INFO] [689/705] Scraping Boogie Fland (PLAYER_ID=1642858)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:02:17,169 [INFO] Sleeping 3.9s after Boogie Fland
# 2025-12-09 16:02:21,092 [INFO] [690/705] Scraping Jalon Moore (PLAYER_ID=1642922)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:02:21,427 [INFO] Sleeping 4.4s after Jalon Moore
# 2025-12-09 16:02:25,821 [INFO] [691/705] Scraping Izan Almansa (PLAYER_ID=1641891)
# 2025-12-09 16:02:25,867 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/izan-almansa-1.html — skipping this player.
# 2025-12-09 16:02:25,867 [INFO] No page for Izan Almansa (1641891), recorded as not found.
# 2025-12-09 16:02:27,494 [INFO] [692/705] Scraping Grant Nelson (PLAYER_ID=1641761)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:02:27,568 [INFO] Sleeping 3.9s after Grant Nelson
# 2025-12-09 16:02:31,472 [INFO] [693/705] Scraping Mark Sears (PLAYER_ID=1641813)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:02:31,543 [INFO] Sleeping 4.1s after Mark Sears
# 2025-12-09 16:02:35,673 [INFO] [694/705] Scraping Milos Uzan (PLAYER_ID=1642870)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:02:35,757 [INFO] Sleeping 4.2s after Milos Uzan
# 2025-12-09 16:02:39,978 [INFO] [695/705] Scraping Brice Williams (PLAYER_ID=1642924)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:02:40,253 [INFO] Sleeping 4.3s after Brice Williams
# 2025-12-09 16:02:44,572 [INFO] [696/705] Scraping Darrion Williams (PLAYER_ID=1642963)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:02:44,666 [INFO] Sleeping 4.1s after Darrion Williams
# 2025-12-09 16:02:48,776 [INFO] Long break after 696 players to avoid 429...
# 2025-12-09 16:02:58,783 [INFO] [697/705] Scraping Neoklis Avdalas (PLAYER_ID=1642921)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:02:58,855 [INFO] Sleeping 4.2s after Neoklis Avdalas
# 2025-12-09 16:03:03,091 [INFO] [698/705] Scraping Hunter Sallis (PLAYER_ID=1642282)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:03:03,191 [INFO] Sleeping 4.5s after Hunter Sallis
# 2025-12-09 16:03:07,684 [INFO] [699/705] Scraping Ryan Nembhard (PLAYER_ID=1642948)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:03:07,779 [INFO] Sleeping 4.3s after Ryan Nembhard
# 2025-12-09 16:03:12,036 [INFO] [700/705] Scraping Otega Oweh (PLAYER_ID=1642923)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:03:12,146 [INFO] Sleeping 3.7s after Otega Oweh
# 2025-12-09 16:03:15,842 [INFO] Autosaving due to processed_since_save >= save_every (normal path).
# 2025-12-09 16:03:15,864 [INFO] Saved stats (rows=579) to cbb_undrafted/undrafted_college_stats.csv and summary (rows=673) to cbb_undrafted/undrafted_summary.csv
# 2025-12-09 16:03:15,865 [INFO] [701/705] Scraping Dink Pate (PLAYER_ID=1641825)
# 2025-12-09 16:03:15,911 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/dink-pate-1.html — skipping this player.
# 2025-12-09 16:03:15,911 [INFO] No page for Dink Pate (1641825), recorded as not found.
# 2025-12-09 16:03:17,892 [INFO] [702/705] Scraping Tahaad Pettiford (PLAYER_ID=1642861)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:03:17,977 [INFO] Sleeping 4.3s after Tahaad Pettiford
# 2025-12-09 16:03:22,233 [INFO] [703/705] Scraping Labaron Philon (PLAYER_ID=1642889)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:03:22,308 [INFO] Sleeping 4.4s after Labaron Philon
# 2025-12-09 16:03:26,744 [INFO] [704/705] Scraping Michael Ruzic (PLAYER_ID=1642913)
# 2025-12-09 16:03:26,794 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/michael-ruzic-1.html — skipping this player.
# 2025-12-09 16:03:26,794 [INFO] No page for Michael Ruzic (1642913), recorded as not found.
# 2025-12-09 16:03:28,358 [INFO] [705/705] Scraping Tamar Bates (PLAYER_ID=1642926)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/586116861.py:289: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, flavor="lxml")
# 2025-12-09 16:03:28,455 [INFO] Sleeping 4.0s after Tamar Bates
# 2025-12-09 16:03:32,503 [INFO] Final save of remaining rows at end of run.
# 2025-12-09 16:03:32,524 [INFO] Saved stats (rows=582) to cbb_undrafted/undrafted_college_stats.csv and summary (rows=678) to cbb_undrafted/undrafted_summary.csv
