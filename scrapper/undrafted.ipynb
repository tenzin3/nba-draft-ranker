# %% [markdown]
# ### 1. Get NBA Draft Data

# %%
import pandas as pd
from pathlib import Path

current_dir = Path.cwd()
draft_dir = current_dir.parent /"data"/ "drafts"

files = list(draft_dir.glob("draft_20*.csv"))

draft_df = pd.DataFrame()
for file in files:
    curr_df = pd.read_csv(file)
    draft_df = pd.concat([draft_df, curr_df])

draft_df = draft_df.sort_values(by=["SEASON", "OVERALL_PICK"]) 
print(draft_df.shape)
draft_df.head()
# Out:
# (1542, 14)
#    PERSON_ID     PLAYER_NAME  SEASON  ROUND_NUMBER  ROUND_PICK  OVERALL_PICK  \
# 0       2030   Kenyon Martin    2000             1           1             1
# 1       2031  Stromile Swift    2000             1           2             2
# 2       2032    Darius Miles    2000             1           3             3
# 3       2033    Marcus Fizer    2000             1           4             4
# 4       2034     Mike Miller    2000             1           5             5
#
#   DRAFT_TYPE     TEAM_ID    TEAM_CITY  TEAM_NAME TEAM_ABBREVIATION  \
# 0      Draft  1610612751   New Jersey       Nets               NJN
# 1      Draft  1610612763    Vancouver  Grizzlies               VAN
# 2      Draft  1610612746  Los Angeles   Clippers               LAC
# 3      Draft  1610612741      Chicago      Bulls               CHI
# 4      Draft  1610612753      Orlando      Magic               ORL
#
#       ORGANIZATION   ORGANIZATION_TYPE  PLAYER_PROFILE_FLAG
# 0       Cincinnati  College/University                    1
# 1  Louisiana State  College/University                    1
# 2   East St. Louis         High School                    1
# 3       Iowa State  College/University                    1
# 4          Florida  College/University                    1

# %% [markdown]
# ### 2. Get NBA Combine Data

# %%
import pandas as pd
from pathlib import Path

current_dir = Path.cwd()
draft_combine_dir = current_dir.parent /"data"/ "draft_combine"

files = list(draft_combine_dir.glob("draft_combine_20*.csv"))

draft_combine_df = pd.DataFrame()
for file in files:
    curr_df = pd.read_csv(file)
    draft_combine_df = pd.concat([draft_combine_df, curr_df])

draft_combine_df = draft_combine_df.sort_values(by=["SEASON"])
print(draft_combine_df.shape)
draft_combine_df.head()
# Out:
# (1795, 47)
#     SEASON  PLAYER_ID FIRST_NAME LAST_NAME     PLAYER_NAME POSITION  \
# 10    2000       2037      Jamal  Crawford  Jamal Crawford    PG-SG
# 37    2000       2058       Mark    Madsen     Mark Madsen       PF
# 36    2000       2090     Justin      Love     Justin Love    PG-SG
# 35    2000       2061        Dan    Langhi      Dan Langhi       SF
# 34    2000      12144    Brandon     Kurtz   Brandon Kurtz     PF-C
#
#     HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES  \
# 10             76.5              6' 4.5''             NaN
# 37             80.0                6' 8''             NaN
# 36             73.5              6' 1.5''             NaN
# 35             81.0                6' 9''             NaN
# 34             81.5              6' 9.5''             NaN
#
#    HEIGHT_W_SHOES_FT_IN  ...  SPOT_NBA_BREAK_RIGHT  SPOT_NBA_CORNER_RIGHT  \
# 10                  NaN  ...                   NaN                    NaN
# 37                  NaN  ...                   NaN                    NaN
# 36                  NaN  ...                   NaN                    NaN
# 35                  NaN  ...                   NaN                    NaN
# 34                  NaN  ...                   NaN                    NaN
#
#    OFF_DRIB_FIFTEEN_BREAK_LEFT  OFF_DRIB_FIFTEEN_TOP_KEY  \
# 10                         NaN                       NaN
# 37                         NaN                       NaN
# 36                         NaN                       NaN
# 35                         NaN                       NaN
# 34                         NaN                       NaN
#
#    OFF_DRIB_FIFTEEN_BREAK_RIGHT  OFF_DRIB_COLLEGE_BREAK_LEFT  \
# 10                          NaN                          NaN
# 37                          NaN                          NaN
# 36                          NaN                          NaN
# 35                          NaN                          NaN
# 34                          NaN                          NaN
#
#     OFF_DRIB_COLLEGE_TOP_KEY  OFF_DRIB_COLLEGE_BREAK_RIGHT  ON_MOVE_FIFTEEN  \
# 10                       NaN                           NaN              NaN
# 37                       NaN                           NaN              NaN
# 36                       NaN                           NaN              NaN
# 35                       NaN                           NaN              NaN
# 34                       NaN                           NaN              NaN
#
#     ON_MOVE_COLLEGE
# 10              NaN
# 37              NaN
# 36              NaN
# 35              NaN
# 34              NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# ### 3. Get Undrafted Players Data

# %%
# Make sure column types match
draft_df["PERSON_ID"] = draft_df["PERSON_ID"].astype(str)
draft_combine_df["PLAYER_ID"] = draft_combine_df["PLAYER_ID"].astype(str)

# Get the sets
drafted_ids = set(draft_df["PERSON_ID"].unique())
combine_ids = set(draft_combine_df["PLAYER_ID"].unique())

# Players who attended combine but were *not* drafted
undrafted_combine_ids = combine_ids - drafted_ids

# Filter full player rows from combine dataframe
undrafted_combine_players = draft_combine_df[
    draft_combine_df["PLAYER_ID"].isin(undrafted_combine_ids)
].copy()


print(f"Numer of Undrafted players: ", len(undrafted_combine_ids))
undrafted_combine_players.head()
# Out:
# Numer of Undrafted players:  678
#     SEASON PLAYER_ID FIRST_NAME LAST_NAME    PLAYER_NAME POSITION  \
# 36    2000      2090     Justin      Love    Justin Love    PG-SG
# 34    2000     12144    Brandon     Kurtz  Brandon Kurtz     PF-C
# 32    2000     12143     Kenyon     Jones   Kenyon Jones     PF-C
# 31    2000     12142       Nate   Johnson   Nate Johnson       SF
# 29    2000     12141      Jacob    Jaacks   Jacob Jaacks       PF
#
#     HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES  \
# 36            73.50              6' 1.5''             NaN
# 34            81.50              6' 9.5''             NaN
# 32            81.00                6' 9''             NaN
# 31            78.50              6' 6.5''             NaN
# 29            81.25             6' 9.25''             NaN
#
#    HEIGHT_W_SHOES_FT_IN  ...  SPOT_NBA_BREAK_RIGHT  SPOT_NBA_CORNER_RIGHT  \
# 36                  NaN  ...                   NaN                    NaN
# 34                  NaN  ...                   NaN                    NaN
# 32                  NaN  ...                   NaN                    NaN
# 31                  NaN  ...                   NaN                    NaN
# 29                  NaN  ...                   NaN                    NaN
#
#    OFF_DRIB_FIFTEEN_BREAK_LEFT  OFF_DRIB_FIFTEEN_TOP_KEY  \
# 36                         NaN                       NaN
# 34                         NaN                       NaN
# 32                         NaN                       NaN
# 31                         NaN                       NaN
# 29                         NaN                       NaN
#
#    OFF_DRIB_FIFTEEN_BREAK_RIGHT  OFF_DRIB_COLLEGE_BREAK_LEFT  \
# 36                          NaN                          NaN
# 34                          NaN                          NaN
# 32                          NaN                          NaN
# 31                          NaN                          NaN
# 29                          NaN                          NaN
#
#     OFF_DRIB_COLLEGE_TOP_KEY  OFF_DRIB_COLLEGE_BREAK_RIGHT  ON_MOVE_FIFTEEN  \
# 36                       NaN                           NaN              NaN
# 34                       NaN                           NaN              NaN
# 32                       NaN                           NaN              NaN
# 31                       NaN                           NaN              NaN
# 29                       NaN                           NaN              NaN
#
#     ON_MOVE_COLLEGE
# 36              NaN
# 34              NaN
# 32              NaN
# 31              NaN
# 29              NaN
#
# [5 rows x 47 columns]

# %% [markdown]
# ### 4.Scrap from basketball-reference

# %%
import os
import re
import time
import random
import logging
from typing import Tuple, Optional, List

import requests
import pandas as pd

# ==========================
# Config
# ==========================

CBB_BASE = "https://www.sports-reference.com"

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 "
        "(KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
    )
}

# Configure logging (adjust level to DEBUG if you want more detail)
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
)


# ==========================
# HTTP Helpers
# ==========================

def safe_get(
    session: requests.Session,
    url: str,
    *,
    retries: int = 6,
    backoff: float = 2.0,
    timeout: int = 30,
) -> Optional[requests.Response]:
    """
    GET with exponential backoff, 429 handling, and 404 skip.

    Returns
    -------
    Response or None
        - Response: if 2xx or other status (that didn't trigger retry) succeeds
        - None: if 404 Not Found
    Raises
    ------
    last exception after `retries` attempts (for non-404 failures).
    """
    last_exc = None

    for i in range(retries):
        try:
            resp = session.get(url, headers=HEADERS, timeout=timeout)

            # Permanent: page does not exist → skip
            if resp.status_code == 404:
                logging.warning(f"404 Not Found: {url} — skipping this player.")
                return None

            # Rate limiting: 429 Too Many Requests → obey Retry-After or backoff
            if resp.status_code == 429:
                retry_after = resp.headers.get("Retry-After")
                try:
                    delay = int(retry_after)
                except Exception:
                    delay = backoff * (2 ** i) + random.uniform(0.5, 1.5)

                logging.warning(f"429 Too Many Requests at {url}, sleeping {delay:.1f}s")
                time.sleep(delay)
                continue

            # Raise for other HTTP errors (5xx, 4xx excluding 404/429)
            resp.raise_for_status()
            return resp

        except Exception as e:
            last_exc = e
            delay = backoff * (2 ** i) + random.uniform(0.5, 1.5)
            logging.warning(f"Error {e} while fetching {url}, sleeping {delay:.1f}s")
            time.sleep(delay)

    # Exhausted retries
    if last_exc is not None:
        raise last_exc
    return None


# ==========================
# URL Builder
# ==========================

def build_cbb_url(first: str, last: str) -> str:
    """
    Sports-Reference CBB uses `fn-ln-1.html` pattern.

    Example: LeBron James → lebron-james-1.html
    """
    fn = re.sub(r"[^a-z\s-]", "", first.lower()).replace(" ", "-")
    ln = re.sub(r"[^a-z\s-]", "", last.lower()).replace(" ", "-")
    return f"{CBB_BASE}/cbb/players/{fn}-{ln}-1.html"


# ==========================
# Resume Helpers
# ==========================

def _load_existing_data(output_dir: str):
    """
    If files already exist, load them so we can resume.
    Returns (stats_df, summary_df), where either can be empty DataFrame.
    """
    stats_path = os.path.join(output_dir, "undrafted_college_stats.csv")
    summary_path = os.path.join(output_dir, "undrafted_summary.csv")

    if os.path.exists(stats_path):
        stats_df = pd.read_csv(stats_path)
        logging.info(f"Loaded existing stats from {stats_path} (rows={len(stats_df)})")
    else:
        stats_df = pd.DataFrame()

    if os.path.exists(summary_path):
        summary_df = pd.read_csv(summary_path)
        logging.info(f"Loaded existing summary from {summary_path} (rows={len(summary_df)})")
    else:
        summary_df = pd.DataFrame()

    return stats_df, summary_df


def _save_data(
    stats_df: pd.DataFrame,
    summary_df: pd.DataFrame,
    output_dir: str,
) -> None:
    """Save both stats and summary to disk."""
    os.makedirs(output_dir, exist_ok=True)
    stats_path = os.path.join(output_dir, "undrafted_college_stats.csv")
    summary_path = os.path.join(output_dir, "undrafted_summary.csv")

    stats_df.to_csv(stats_path, index=False)
    summary_df.to_csv(summary_path, index=False)

    logging.info(
        f"Saved stats (rows={len(stats_df)}) to {stats_path} "
        f"and summary (rows={len(summary_df)}) to {summary_path}"
    )


# ==========================
# Core row selection helper
# ==========================

def _pick_last_season_row_from_totals(season_table: pd.DataFrame) -> pd.DataFrame:
    """
    Given the Totals table, pick the row representing the final playing season:

    - Prefer the row *immediately before* 'Career'
    - If 'Career' is missing, fall back to the last row
    - Filter out duplicated header rows ('Season') but keep 'Career' for logic
    """
    season_table = season_table.copy()

    # Drop duplicated header rows and NaNs
    season_table = season_table[season_table["Season"].notna()]
    season_table = season_table[season_table["Season"] != "Season"]

    if season_table.empty:
        return season_table

    # Find 'Career' row
    career_idx = season_table.index[season_table["Season"] == "Career"]

    if not career_idx.empty:
        # Get position of first 'Career' row
        pos = season_table.index.get_loc(career_idx[0])
        if pos == 0:
            # Edge case: Career first -> fall back to last non-career row
            fallback = season_table[season_table["Season"] != "Career"]
            if fallback.empty:
                return season_table.tail(1)
            return fallback.tail(1)
        else:
            # Normal: take row immediately before Career
            return season_table.iloc[[pos - 1]]
    else:
        # No Career row: fall back to last row
        return season_table.tail(1)


# ==========================
# Main Scraper
# ==========================

def scrape_undrafted_players(
    df: pd.DataFrame,
    output_dir: str = "cbb_undrafted",
    *,
    save_every: int = 50,
    resume: bool = True,
    long_break_every: int = 12,
    long_break_seconds: int = 10,
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Scrape *Totals* table last-season stats for undrafted players from Sports-Reference CBB.

    We extract the row right before 'Career' so that:
      - We keep the Season value (e.g., '1999-00')
      - We ignore the Career aggregate row.

    Parameters
    ----------
    df : DataFrame
        Must contain columns: PLAYER_ID, FIRST_NAME, LAST_NAME
    output_dir : str
        Directory to save CSVs.
    save_every : int
        Autosave after this many processed players (including skips).
    resume : bool
        If True, will load existing CSVs and skip players already marked found=True.
    long_break_every : int
        After this many players, take a longer sleep to avoid 429.
    long_break_seconds : int
        Duration of the long sleep.

    Returns
    -------
    (stats_df, summary_df) : Tuple[DataFrame, DataFrame]
        Final in-memory copies of stats and summary.
    """
    os.makedirs(output_dir, exist_ok=True)
    session = requests.Session()

    # Load existing data (for resume)
    existing_stats_df, existing_summary_df = _load_existing_data(output_dir)

    # Tracks new rows collected in this run
    new_stats_rows: List[pd.DataFrame] = []
    new_summary_rows: List[dict] = []

    # Determine which player_ids are already successfully scraped
    if resume and not existing_summary_df.empty and "PLAYER_ID" in existing_summary_df.columns:
        completed_ids = set(
            existing_summary_df.loc[
                existing_summary_df.get("found", False) == True,  # noqa: E712
                "PLAYER_ID",
            ].tolist()
        )
        logging.info(f"Resuming. Already completed players: {len(completed_ids)}")
    else:
        completed_ids = set()

    total_players = len(df)
    processed_since_save = 0

    for i, row in enumerate(df.itertuples(index=False), start=1):
        pid = row.PLAYER_ID
        first = row.FIRST_NAME
        last = row.LAST_NAME

        # Resume: skip if already scraped successfully
        if resume and pid in completed_ids:
            logging.info(f"[{i}/{total_players}] {first} {last} (PLAYER_ID={pid}) already scraped — skipping.")
            continue

        logging.info(f"[{i}/{total_players}] Scraping {first} {last} (PLAYER_ID={pid})")

        url = build_cbb_url(first, last)

        try:
            resp = safe_get(session, url)
        except Exception as e:
            logging.error(f"Failed for {first} {last} ({pid}) at {url}: {e}")
            new_summary_rows.append(
                {
                    "PLAYER_ID": pid,
                    "FIRST_NAME": first,
                    "LAST_NAME": last,
                    "found": False,
                    "url": url,
                    "error": str(e),
                }
            )
            processed_since_save += 1
            # small polite delay even on error
            time.sleep(1.0 + random.uniform(0.5, 1.0))
            # periodic save
            if processed_since_save >= save_every:
                logging.info("Autosaving due to processed_since_save >= save_every (error path).")
                existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
                    existing_stats_df,
                    existing_summary_df,
                    new_stats_rows,
                    new_summary_rows,
                    output_dir,
                )
                new_stats_rows, new_summary_rows = [], []
            continue

        # 404 (None) → skip
        if resp is None:
            new_summary_rows.append(
                {
                    "PLAYER_ID": pid,
                    "FIRST_NAME": first,
                    "LAST_NAME": last,
                    "found": False,
                    "url": None,
                    "error": "404 Not Found",
                }
            )
            logging.info(f"No page for {first} {last} ({pid}), recorded as not found.")
            processed_since_save += 1
            time.sleep(1.0 + random.uniform(0.5, 1.0))
            if processed_since_save >= save_every:
                logging.info("Autosaving due to processed_since_save >= save_every (404 path).")
                existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
                    existing_stats_df,
                    existing_summary_df,
                    new_stats_rows,
                    new_summary_rows,
                    output_dir,
                )
                new_stats_rows, new_summary_rows = [], []
            continue

        # Parse ONLY the Totals table
        try:
            # match="Totals" should pick the totals table (like in your screenshot)
            tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
        except ValueError as e:
            logging.warning(f"No Totals table found for {first} {last} ({pid}) at {url}: {e}")
            new_summary_rows.append(
                {
                    "PLAYER_ID": pid,
                    "FIRST_NAME": first,
                    "LAST_NAME": last,
                    "found": False,
                    "url": url,
                    "error": "no Totals table",
                }
            )
            processed_since_save += 1
            time.sleep(1.0 + random.uniform(0.5, 1.0))
            if processed_since_save >= save_every:
                logging.info("Autosaving due to processed_since_save >= save_every (no-table path).")
                existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
                    existing_stats_df,
                    existing_summary_df,
                    new_stats_rows,
                    new_summary_rows,
                    output_dir,
                )
                new_stats_rows, new_summary_rows = [], []
            continue

        if not tables:
            logging.warning(f"Empty tables list for {first} {last} ({pid}) at {url}")
            new_summary_rows.append(
                {
                    "PLAYER_ID": pid,
                    "FIRST_NAME": first,
                    "LAST_NAME": last,
                    "found": False,
                    "url": url,
                    "error": "empty tables from Totals",
                }
            )
            processed_since_save += 1
            time.sleep(1.0 + random.uniform(0.5, 1.0))
            if processed_since_save >= save_every:
                logging.info("Autosaving due to processed_since_save >= save_every (empty-tables path).")
                existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
                    existing_stats_df,
                    existing_summary_df,
                    new_stats_rows,
                    new_summary_rows,
                    output_dir,
                )
                new_stats_rows, new_summary_rows = [], []
            continue

        # Totals table should be the first one returned
        season_table = tables[0]

        # Pick row right before 'Career'
        last_season_row = _pick_last_season_row_from_totals(season_table)

        if last_season_row.empty:
            logging.warning(f"No usable rows in Totals table for {first} {last} ({pid}) at {url}")
            new_summary_rows.append(
                {
                    "PLAYER_ID": pid,
                    "FIRST_NAME": first,
                    "LAST_NAME": last,
                    "found": False,
                    "url": url,
                    "error": "empty Totals after cleaning",
                }
            )
            processed_since_save += 1
            time.sleep(1.0 + random.uniform(0.5, 1.0))
            if processed_since_save >= save_every:
                logging.info("Autosaving due to processed_since_save >= save_every (empty-totals path).")
                existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
                    existing_stats_df,
                    existing_summary_df,
                    new_stats_rows,
                    new_summary_rows,
                    output_dir,
                )
                new_stats_rows, new_summary_rows = [], []
            continue

        # Insert identifiers
        last_row = last_season_row.copy()
        last_row.insert(0, "PLAYER_ID", pid)
        last_row.insert(1, "FIRST_NAME", first)
        last_row.insert(2, "LAST_NAME", last)
        last_row.insert(3, "cbb_url", url)

        new_stats_rows.append(last_row)
        new_summary_rows.append(
            {
                "PLAYER_ID": pid,
                "FIRST_NAME": first,
                "LAST_NAME": last,
                "found": True,
                "url": url,
                "error": "",
            }
        )

        # Polite delay between requests
        sleep_time = 2.5 + random.uniform(1.0, 2.0)
        logging.info(f"Season picked for {first} {last}: {last_row['Season'].iloc[0]} — sleeping {sleep_time:.1f}s")
        time.sleep(sleep_time)

        # Longer break every N players
        if long_break_every > 0 and i % long_break_every == 0:
            logging.info(f"Long break after {i} players to avoid 429...")
            time.sleep(long_break_seconds)

        processed_since_save += 1

        # Autosave periodically
        if processed_since_save >= save_every:
            logging.info("Autosaving due to processed_since_save >= save_every (normal path).")
            existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
                existing_stats_df,
                existing_summary_df,
                new_stats_rows,
                new_summary_rows,
                output_dir,
            )
            new_stats_rows, new_summary_rows = [], []

    # Final save for any remaining rows
    if new_stats_rows or new_summary_rows:
        logging.info("Final save of remaining rows at end of run.")
        existing_stats_df, existing_summary_df, processed_since_save = _merge_and_save(
            existing_stats_df,
            existing_summary_df,
            new_stats_rows,
            new_summary_rows,
            output_dir,
        )

    return existing_stats_df, existing_summary_df


def _merge_and_save(
    existing_stats_df: pd.DataFrame,
    existing_summary_df: pd.DataFrame,
    new_stats_rows: List[pd.DataFrame],
    new_summary_rows: List[dict],
    output_dir: str,
):
    """
    Merge new rows into existing DataFrames and save to disk.
    Returns updated stats_df, summary_df, and resets processed_since_save.
    """
    if new_stats_rows:
        new_stats_df = pd.concat(new_stats_rows, ignore_index=True)
        if existing_stats_df.empty:
            combined_stats_df = new_stats_df
        else:
            combined_stats_df = pd.concat(
                [existing_stats_df, new_stats_df],
                ignore_index=True,
            ).drop_duplicates(subset=["PLAYER_ID", "Season"], keep="last")
    else:
        combined_stats_df = existing_stats_df

    if new_summary_rows:
        new_summary_df = pd.DataFrame(new_summary_rows)
        if existing_summary_df.empty:
            combined_summary_df = new_summary_df
        else:
            combined_summary_df = pd.concat(
                [existing_summary_df, new_summary_df],
                ignore_index=True,
            ).drop_duplicates(subset=["PLAYER_ID"], keep="last")
    else:
        combined_summary_df = existing_summary_df

    _save_data(combined_stats_df, combined_summary_df, output_dir)

    # Reset processed counter
    processed_since_save = 0
    return combined_stats_df, combined_summary_df, processed_since_save


# ==========================
# Optional CLI Example
# ==========================

if __name__ == "__main__":
    """
    Example usage:

    Suppose you already have a DataFrame `df_players` with columns:
        - PLAYER_ID
        - FIRST_NAME
        - LAST_NAME

    You might load it from CSV like this:
        df_players = pd.read_csv("undrafted_players.csv")

    Then run:
        scrape_undrafted_players(df_players, output_dir="cbb_undrafted")
    """
    print("This module is intended to be imported and used from another script.")
# Out:
# This module is intended to be imported and used from another script.

# %%
college_stats_undrafted, summary = scrape_undrafted_players(
    undrafted_combine_players,
    output_dir="ndrafted"
)
# Out:
# 2025-12-09 17:10:11,325 [INFO] [1/705] Scraping Justin Love (PLAYER_ID=2090)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:10:11,442 [INFO] Season picked for Justin Love: 1999-00 — sleeping 4.2s
# 2025-12-09 17:10:15,660 [INFO] [2/705] Scraping Brandon Kurtz (PLAYER_ID=12144)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:10:15,740 [INFO] Season picked for Brandon Kurtz: 1999-00 — sleeping 4.0s
# 2025-12-09 17:10:19,780 [INFO] [3/705] Scraping Kenyon Jones (PLAYER_ID=12143)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:10:19,910 [INFO] Season picked for Kenyon Jones: 1999-00 — sleeping 3.9s
# 2025-12-09 17:10:23,797 [INFO] [4/705] Scraping Nate Johnson (PLAYER_ID=12142)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:10:23,875 [INFO] Season picked for Nate Johnson: 1998-99 — sleeping 3.5s
# 2025-12-09 17:10:27,392 [INFO] [5/705] Scraping Jacob Jaacks (PLAYER_ID=12141)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:10:27,681 [INFO] Season picked for Jacob Jaacks: 1999-00 — sleeping 3.7s
# 2025-12-09 17:10:31,383 [INFO] [6/705] Scraping Jimmie Hunter (PLAYER_ID=2111)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:10:31,444 [INFO] Season picked for Jimmie Hunter: 1998-99 — sleeping 4.0s
# 2025-12-09 17:10:35,492 [INFO] [7/705] Scraping Shaheen Holloway (PLAYER_ID=12140)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:10:35,569 [INFO] Season picked for Shaheen Holloway: 1999-00 — sleeping 3.6s
# 2025-12-09 17:10:39,174 [INFO] [8/705] Scraping Michael Hermon (PLAYER_ID=12139)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:10:39,451 [INFO] Season picked for Michael Hermon: 1994-95 — sleeping 4.4s
# 2025-12-09 17:10:43,826 [INFO] [9/705] Scraping Johnny Hemsley (PLAYER_ID=12138)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:10:44,167 [INFO] Season picked for Johnny Hemsley: 1999-00 — sleeping 4.0s
# 2025-12-09 17:10:48,164 [INFO] [10/705] Scraping Ron Hale (PLAYER_ID=2110)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:10:48,248 [INFO] Season picked for Ron Hale: 1999-00 — sleeping 4.5s
# 2025-12-09 17:10:52,748 [INFO] [11/705] Scraping A.J. Granger (PLAYER_ID=12137)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:10:52,825 [INFO] Season picked for A.J. Granger: 1999-00 — sleeping 3.7s
# 2025-12-09 17:10:56,493 [INFO] [12/705] Scraping Marcus Goree (PLAYER_ID=12136)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:10:56,586 [INFO] Season picked for Marcus Goree: 1999-00 — sleeping 3.6s
# 2025-12-09 17:11:00,145 [INFO] Long break after 12 players to avoid 429...
# 2025-12-09 17:11:10,152 [INFO] [13/705] Scraping Ceedric Goodwyn (PLAYER_ID=12135)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:11:10,248 [INFO] Season picked for Ceedric Goodwyn: 1999-00 — sleeping 4.4s
# 2025-12-09 17:11:14,637 [INFO] [14/705] Scraping Eddie Gill (PLAYER_ID=2109)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:11:14,923 [INFO] Season picked for Eddie Gill: 1999-00 — sleeping 3.9s
# 2025-12-09 17:11:18,789 [INFO] [15/705] Scraping Vassil Evtimov (PLAYER_ID=12018)
# 2025-12-09 17:11:18,846 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/vassil-evtimov-1.html — skipping this player.
# 2025-12-09 17:11:18,846 [INFO] No page for Vassil Evtimov (12018), recorded as not found.
# 2025-12-09 17:11:20,751 [INFO] [16/705] Scraping Gabe Muoneke (PLAYER_ID=2508)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:11:21,136 [INFO] Season picked for Gabe Muoneke: 1999-00 — sleeping 3.9s
# 2025-12-09 17:11:25,049 [INFO] [17/705] Scraping Schea Cotton (PLAYER_ID=12134)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:11:25,146 [INFO] Season picked for Schea Cotton: 1999-00 — sleeping 3.7s
# 2025-12-09 17:11:28,869 [INFO] [18/705] Scraping Jameel Watkins (PLAYER_ID=12030)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:11:29,110 [INFO] Season picked for Jameel Watkins: 1999-00 — sleeping 4.3s
# 2025-12-09 17:11:33,433 [INFO] [19/705] Scraping Jaquay Walls (PLAYER_ID=12029)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:11:33,798 [INFO] Season picked for Jaquay Walls: 1999-00 — sleeping 4.4s
# 2025-12-09 17:11:38,177 [INFO] [20/705] Scraping Bootsy Thornton (PLAYER_ID=12028)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:11:38,735 [INFO] Season picked for Bootsy Thornton: 1999-00 — sleeping 3.7s
# 2025-12-09 17:11:42,485 [INFO] [21/705] Scraping Jarrett Stephens (PLAYER_ID=12027)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:11:42,576 [INFO] Season picked for Jarrett Stephens: 1999-00 — sleeping 3.8s
# 2025-12-09 17:11:46,389 [INFO] [22/705] Scraping Nick Sheppard (PLAYER_ID=12026)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:11:46,489 [INFO] Season picked for Nick Sheppard: 1999-00 — sleeping 4.2s
# 2025-12-09 17:11:50,734 [INFO] [23/705] Scraping Karim Shabazz (PLAYER_ID=12025)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:11:50,817 [INFO] Season picked for Karim Shabazz: 2000-01 — sleeping 4.4s
# 2025-12-09 17:11:55,244 [INFO] [24/705] Scraping Alex Scales (PLAYER_ID=2637)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:11:55,471 [INFO] Season picked for Alex Scales: 1999-00 — sleeping 3.6s
# 2025-12-09 17:11:59,122 [INFO] Long break after 24 players to avoid 429...
# 2025-12-09 17:12:09,127 [INFO] [25/705] Scraping Matt Santangelo (PLAYER_ID=12024)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:12:09,351 [INFO] Season picked for Matt Santangelo: 1999-00 — sleeping 3.9s
# 2025-12-09 17:12:13,262 [INFO] [26/705] Scraping Brian Montonati (PLAYER_ID=12145)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:12:13,512 [INFO] Season picked for Brian Montonati: 1999-00 — sleeping 4.0s
# 2025-12-09 17:12:17,519 [INFO] [27/705] Scraping Pepe Sanchez (PLAYER_ID=12023)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:12:17,739 [INFO] Season picked for Pepe Sanchez: 1999-00 — sleeping 3.7s
# 2025-12-09 17:12:21,398 [INFO] [28/705] Scraping Terrance Roberson (PLAYER_ID=2121)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:12:21,747 [INFO] Season picked for Terrance Roberson: 1999-00 — sleeping 3.6s
# 2025-12-09 17:12:25,366 [INFO] [29/705] Scraping Aubrey Reese (PLAYER_ID=12021)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:12:25,710 [INFO] Season picked for Aubrey Reese: 1999-00 — sleeping 4.4s
# 2025-12-09 17:12:30,161 [INFO] [30/705] Scraping Damon Reed (PLAYER_ID=12149)
# 2025-12-09 17:12:30,209 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/damon-reed-1.html — skipping this player.
# 2025-12-09 17:12:30,210 [INFO] No page for Damon Reed (12149), recorded as not found.
# 2025-12-09 17:12:32,122 [INFO] [31/705] Scraping Reed Rawlings (PLAYER_ID=12148)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:12:32,505 [INFO] Season picked for Reed Rawlings: 1999-00 — sleeping 3.8s
# 2025-12-09 17:12:36,358 [INFO] [32/705] Scraping Matthew Nielsen (PLAYER_ID=12147)
# 2025-12-09 17:12:36,410 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/matthew-nielsen-1.html — skipping this player.
# 2025-12-09 17:12:36,411 [INFO] No page for Matthew Nielsen (12147), recorded as not found.
# 2025-12-09 17:12:38,333 [INFO] [33/705] Scraping Ndongo N'diaye (PLAYER_ID=12146)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:12:38,418 [INFO] Season picked for Ndongo N'diaye: 1999-00 — sleeping 4.4s
# 2025-12-09 17:12:42,822 [INFO] [34/705] Scraping Julius Doc Robinson (PLAYER_ID=12022)
# 2025-12-09 17:12:42,871 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/julius-doc-robinson-1.html — skipping this player.
# 2025-12-09 17:12:42,872 [INFO] No page for Julius Doc Robinson (12022), recorded as not found.
# 2025-12-09 17:12:44,527 [INFO] [35/705] Scraping Caswell Cyrus (PLAYER_ID=12017)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:12:44,615 [INFO] Season picked for Caswell Cyrus: 1999-00 — sleeping 3.7s
# 2025-12-09 17:12:48,307 [INFO] [36/705] Scraping Ed Cota (PLAYER_ID=12133)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:12:48,380 [INFO] Season picked for Ed Cota: 1999-00 — sleeping 3.7s
# 2025-12-09 17:12:52,063 [INFO] Long break after 36 players to avoid 429...
# 2025-12-09 17:13:02,066 [INFO] [37/705] Scraping Eric Coley (PLAYER_ID=12132)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:13:02,151 [INFO] Season picked for Eric Coley: 1999-00 — sleeping 4.3s
# 2025-12-09 17:13:06,412 [INFO] [38/705] Scraping Mario Bland (PLAYER_ID=12131)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:13:06,811 [INFO] Season picked for Mario Bland: 1999-00 — sleeping 4.1s
# 2025-12-09 17:13:10,879 [INFO] [39/705] Scraping Lamont Barnes (PLAYER_ID=12020)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:13:11,148 [INFO] Season picked for Lamont Barnes: 1999-00 — sleeping 3.6s
# 2025-12-09 17:13:14,707 [INFO] [40/705] Scraping Harold Arceneaux (PLAYER_ID=12019)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:13:14,790 [INFO] Season picked for Harold Arceneaux: 1999-00 — sleeping 3.9s
# 2025-12-09 17:13:18,668 [INFO] [41/705] Scraping Malik Allen (PLAYER_ID=2124)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:13:19,094 [INFO] Season picked for Malik Allen: 1999-00 — sleeping 3.9s
# 2025-12-09 17:13:23,038 [INFO] [42/705] Scraping Jason Gardner (PLAYER_ID=-1)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:13:23,114 [INFO] Season picked for Jason Gardner: 2002-03 — sleeping 4.2s
# 2025-12-09 17:13:27,322 [INFO] [43/705] Scraping Michael Hicks (PLAYER_ID=12154)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:13:27,410 [INFO] Season picked for Michael Hicks: 2001-02 — sleeping 4.3s
# 2025-12-09 17:13:31,697 [INFO] [44/705] Scraping Andre Hutson (PLAYER_ID=12155)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:13:31,783 [INFO] Season picked for Andre Hutson: 2000-01 — sleeping 4.5s
# 2025-12-09 17:13:36,251 [INFO] [45/705] Scraping Nate James (PLAYER_ID=12156)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:13:36,322 [INFO] Season picked for Nate James: 2000-01 — sleeping 4.4s
# 2025-12-09 17:13:40,774 [INFO] [46/705] Scraping Darren Kelly (PLAYER_ID=12158)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:13:40,891 [INFO] Season picked for Darren Kelly: 2000-01 — sleeping 3.9s
# 2025-12-09 17:13:44,831 [INFO] [47/705] Scraping Darrell Johns (PLAYER_ID=12157)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:13:45,112 [INFO] Season picked for Darrell Johns: 2000-01 — sleeping 4.2s
# 2025-12-09 17:13:49,318 [INFO] [48/705] Scraping Horace Jenkins (PLAYER_ID=2798)
# 2025-12-09 17:13:49,376 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/horace-jenkins-1.html — skipping this player.
# 2025-12-09 17:13:49,377 [INFO] No page for Horace Jenkins (2798), recorded as not found.
# 2025-12-09 17:13:51,383 [INFO] [49/705] Scraping Charles Hathaway (PLAYER_ID=12153)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:13:51,470 [INFO] Season picked for Charles Hathaway: 2000-01 — sleeping 4.3s
# 2025-12-09 17:13:55,803 [INFO] [50/705] Scraping Adam Allenspach (PLAYER_ID=12033)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:13:56,127 [INFO] Season picked for Adam Allenspach: 2000-01 — sleeping 4.5s
# 2025-12-09 17:14:00,618 [INFO] Autosaving due to processed_since_save >= save_every (normal path).
# 2025-12-09 17:14:00,629 [INFO] Saved stats (rows=45) to ndrafted/undrafted_college_stats.csv and summary (rows=50) to ndrafted/undrafted_summary.csv
# 2025-12-09 17:14:00,630 [INFO] [51/705] Scraping Kenny Gregory (PLAYER_ID=12152)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:14:00,929 [INFO] Season picked for Kenny Gregory: 2000-01 — sleeping 3.7s
# 2025-12-09 17:14:04,670 [INFO] [52/705] Scraping Cookie Belcher (PLAYER_ID=12034)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:14:04,768 [INFO] Season picked for Cookie Belcher: 2000-01 — sleeping 3.9s
# 2025-12-09 17:14:08,638 [INFO] [53/705] Scraping Charlie Bell (PLAYER_ID=2294)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:14:08,737 [INFO] Season picked for Charlie Bell: 2000-01 — sleeping 3.6s
# 2025-12-09 17:14:12,389 [INFO] [54/705] Scraping Calvin Bowman (PLAYER_ID=12035)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:14:12,660 [INFO] Season picked for Calvin Bowman: 2000-01 — sleeping 4.4s
# 2025-12-09 17:14:17,083 [INFO] [55/705] Scraping Zach Marbury (PLAYER_ID=12159)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:14:17,181 [INFO] Season picked for Zach Marbury: 2000-01 — sleeping 3.8s
# 2025-12-09 17:14:20,941 [INFO] [56/705] Scraping Troy Ostler (PLAYER_ID=12162)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:14:21,247 [INFO] Season picked for Troy Ostler: 2000-01 — sleeping 3.8s
# 2025-12-09 17:14:25,086 [INFO] [57/705] Scraping DeMarcus Minor (PLAYER_ID=12161)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:14:25,451 [INFO] Season picked for DeMarcus Minor: 2000-01 — sleeping 4.0s
# 2025-12-09 17:14:29,421 [INFO] [58/705] Scraping Michael Wright (PLAYER_ID=12041)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:14:29,675 [INFO] Season picked for Michael Wright: 2000-01 — sleeping 3.9s
# 2025-12-09 17:14:33,580 [INFO] [59/705] Scraping Brent Wright (PLAYER_ID=12040)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:14:33,812 [INFO] Season picked for Brent Wright: 2000-01 — sleeping 4.1s
# 2025-12-09 17:14:37,892 [INFO] [60/705] Scraping Souleymane Wane (PLAYER_ID=12172)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:14:38,250 [INFO] Season picked for Souleymane Wane: 2000-01 — sleeping 3.8s
# 2025-12-09 17:14:42,070 [INFO] Long break after 60 players to avoid 429...
# 2025-12-09 17:14:52,072 [INFO] [61/705] Scraping Jerry Green (PLAYER_ID=12151)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:14:52,334 [INFO] Season picked for Jerry Green: 2001-02 — sleeping 3.7s
# 2025-12-09 17:14:56,011 [INFO] [62/705] Scraping Damone Thornton (PLAYER_ID=12170)
# 2025-12-09 17:14:56,068 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/damone-thornton-1.html — skipping this player.
# 2025-12-09 17:14:56,069 [INFO] No page for Damone Thornton (12170), recorded as not found.
# 2025-12-09 17:14:57,678 [INFO] [63/705] Scraping Greg Stevenson (PLAYER_ID=12169)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:14:57,972 [INFO] Season picked for Greg Stevenson: 2000-01 — sleeping 4.3s
# 2025-12-09 17:15:02,254 [INFO] [64/705] Scraping Lee Scruggs (PLAYER_ID=12168)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:15:02,326 [INFO] Season picked for Lee Scruggs: 2000-01 — sleeping 3.6s
# 2025-12-09 17:15:05,892 [INFO] [65/705] Scraping Kenny Satterfield (PLAYER_ID=12167)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:15:05,991 [INFO] Season picked for Kenny Satterfield: 2000-01 — sleeping 4.1s
# 2025-12-09 17:15:10,056 [INFO] [66/705] Scraping Norman Richardson (PLAYER_ID=2369)
# 2025-12-09 17:15:10,106 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/norman-richardson-1.html — skipping this player.
# 2025-12-09 17:15:10,106 [INFO] No page for Norman Richardson (2369), recorded as not found.
# 2025-12-09 17:15:11,703 [INFO] [67/705] Scraping Martin Rancik (PLAYER_ID=12166)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:15:12,105 [INFO] Season picked for Martin Rancik: 2000-01 — sleeping 4.1s
# 2025-12-09 17:15:16,226 [INFO] [68/705] Scraping Demetrius Porter (PLAYER_ID=12165)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:15:16,314 [INFO] Season picked for Demetrius Porter: 2000-01 — sleeping 4.2s
# 2025-12-09 17:15:20,543 [INFO] [69/705] Scraping Rashad Phillips (PLAYER_ID=12164)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:15:20,791 [INFO] Season picked for Rashad Phillips: 2000-01 — sleeping 3.6s
# 2025-12-09 17:15:24,387 [INFO] [70/705] Scraping Lazaros Papadopoulos (PLAYER_ID=40046)
# 2025-12-09 17:15:24,455 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/lazaros-papadopoulos-1.html — skipping this player.
# 2025-12-09 17:15:24,456 [INFO] No page for Lazaros Papadopoulos (40046), recorded as not found.
# 2025-12-09 17:15:25,985 [INFO] [71/705] Scraping Jamario Moon (PLAYER_ID=200081)
# 2025-12-09 17:15:26,035 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/jamario-moon-1.html — skipping this player.
# 2025-12-09 17:15:26,035 [INFO] No page for Jamario Moon (200081), recorded as not found.
# 2025-12-09 17:15:27,858 [INFO] [72/705] Scraping Mike Mardesich (PLAYER_ID=12160)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:15:28,224 [INFO] Season picked for Mike Mardesich: 2000-01 — sleeping 3.7s
# 2025-12-09 17:15:31,906 [INFO] Long break after 72 players to avoid 429...
# 2025-12-09 17:15:41,907 [INFO] [73/705] Scraping Tory Walker (PLAYER_ID=12171)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:15:42,353 [INFO] Season picked for Tory Walker: 2000-01 — sleeping 3.6s
# 2025-12-09 17:15:45,988 [INFO] [74/705] Scraping SirValiant Brown (PLAYER_ID=12031)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:15:46,241 [INFO] Season picked for SirValiant Brown: 2000-01 — sleeping 3.9s
# 2025-12-09 17:15:50,158 [INFO] [75/705] Scraping Ryan Carroll (PLAYER_ID=12032)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:15:50,544 [INFO] Season picked for Ryan Carroll: 1999-00 — sleeping 4.4s
# 2025-12-09 17:15:54,954 [INFO] [76/705] Scraping Gyasi Cline-Heard (PLAYER_ID=12036)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:15:55,463 [INFO] Season picked for Gyasi Cline-Heard: 2000-01 — sleeping 4.3s
# 2025-12-09 17:15:59,800 [INFO] [77/705] Scraping Tate Decker (PLAYER_ID=12037)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:15:59,881 [INFO] Season picked for Tate Decker: 1999-00 — sleeping 4.5s
# 2025-12-09 17:16:04,364 [INFO] [78/705] Scraping Maurice Evans (PLAYER_ID=2230)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:16:04,460 [INFO] Season picked for Maurice Evans: 2000-01 — sleeping 4.1s
# 2025-12-09 17:16:08,577 [INFO] [79/705] Scraping Anthony Evans (PLAYER_ID=12039)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:16:08,872 [INFO] Season picked for Anthony Evans: 2000-01 — sleeping 3.6s
# 2025-12-09 17:16:12,437 [INFO] [80/705] Scraping Benjamin Eze (PLAYER_ID=12150)
# 2025-12-09 17:16:12,518 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/benjamin-eze-1.html — skipping this player.
# 2025-12-09 17:16:12,520 [INFO] No page for Benjamin Eze (12150), recorded as not found.
# 2025-12-09 17:16:14,278 [INFO] [81/705] Scraping Kimani Ffriend (PLAYER_ID=2386)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:16:14,604 [INFO] Season picked for Kimani Ffriend: 2000-01 — sleeping 3.7s
# 2025-12-09 17:16:18,290 [INFO] [82/705] Scraping Robb Dryden (PLAYER_ID=12038)
# 2025-12-09 17:16:18,345 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/robb-dryden-1.html — skipping this player.
# 2025-12-09 17:16:18,345 [INFO] No page for Robb Dryden (12038), recorded as not found.
# 2025-12-09 17:16:20,028 [INFO] [83/705] Scraping Andy Ellis (PLAYER_ID=12046)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:16:20,111 [INFO] Season picked for Andy Ellis: 2001-02 — sleeping 4.0s
# 2025-12-09 17:16:24,116 [INFO] [84/705] Scraping Teddy Dupay (PLAYER_ID=12045)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:16:24,202 [INFO] Season picked for Teddy Dupay: 2000-01 — sleeping 4.3s
# 2025-12-09 17:16:28,474 [INFO] Long break after 84 players to avoid 429...
# 2025-12-09 17:16:38,484 [INFO] [85/705] Scraping Craig Dawson (PLAYER_ID=12044)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:16:38,692 [INFO] Season picked for Craig Dawson: 2001-02 — sleeping 4.3s
# 2025-12-09 17:16:43,042 [INFO] [86/705] Scraping Reggie Evans (PLAYER_ID=2501)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:16:43,309 [INFO] Season picked for Reggie Evans: 2001-02 — sleeping 3.8s
# 2025-12-09 17:16:47,127 [INFO] [87/705] Scraping Lenny Cooke (PLAYER_ID=12043)
# 2025-12-09 17:16:47,215 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/lenny-cooke-1.html — skipping this player.
# 2025-12-09 17:16:47,216 [INFO] No page for Lenny Cooke (12043), recorded as not found.
# 2025-12-09 17:16:49,140 [INFO] [88/705] Scraping David Graves (PLAYER_ID=12066)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:16:49,425 [INFO] Season picked for David Graves: 2001-02 — sleeping 3.8s
# 2025-12-09 17:16:53,207 [INFO] [89/705] Scraping Lynn Greer (PLAYER_ID=2696)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:16:53,735 [INFO] Season picked for Lynn Greer: 2001-02 — sleeping 4.5s
# 2025-12-09 17:16:58,200 [INFO] [90/705] Scraping Rod Grizzard (PLAYER_ID=12067)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:16:58,536 [INFO] Season picked for Rod Grizzard: 2001-02 — sleeping 3.6s
# 2025-12-09 17:17:02,136 [INFO] [91/705] Scraping Anthony Grundy (PLAYER_ID=101219)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:17:02,221 [INFO] Season picked for Anthony Grundy: 2001-02 — sleeping 3.6s
# 2025-12-09 17:17:05,795 [INFO] [92/705] Scraping Peter Fehse (PLAYER_ID=12047)
# 2025-12-09 17:17:05,871 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/peter-fehse-1.html — skipping this player.
# 2025-12-09 17:17:05,871 [INFO] No page for Peter Fehse (12047), recorded as not found.
# 2025-12-09 17:17:07,509 [INFO] [93/705] Scraping Chris Christoffersen (PLAYER_ID=12042)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:17:07,596 [INFO] Season picked for Chris Christoffersen: 2001-02 — sleeping 3.6s
# 2025-12-09 17:17:11,180 [INFO] [94/705] Scraping Lee Benson (PLAYER_ID=12287)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:17:11,394 [INFO] Season picked for Lee Benson: 1951-52 — sleeping 4.5s
# 2025-12-09 17:17:15,896 [INFO] [95/705] Scraping Chris Burgess (PLAYER_ID=12290)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:17:16,290 [INFO] Season picked for Chris Burgess: 2001-02 — sleeping 3.8s
# 2025-12-09 17:17:20,110 [INFO] [96/705] Scraping Sylvere Bryan (PLAYER_ID=12289)
# 2025-12-09 17:17:20,165 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/sylvere-bryan-1.html — skipping this player.
# 2025-12-09 17:17:20,165 [INFO] No page for Sylvere Bryan (12289), recorded as not found.
# 2025-12-09 17:17:22,100 [INFO] [97/705] Scraping Brian Brown (PLAYER_ID=12288)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:17:22,602 [INFO] Season picked for Brian Brown: 2004-05 — sleeping 3.8s
# 2025-12-09 17:17:26,370 [INFO] [98/705] Scraping J.R. Bremer (PLAYER_ID=2452)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:17:26,471 [INFO] Season picked for J.R. Bremer: 2001-02 — sleeping 3.6s
# 2025-12-09 17:17:30,086 [INFO] [99/705] Scraping Maurice Baker (PLAYER_ID=2486)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:17:30,322 [INFO] Season picked for Maurice Baker: 2001-02 — sleeping 4.2s
# 2025-12-09 17:17:34,499 [INFO] [100/705] Scraping Mire Chatman (PLAYER_ID=12291)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:17:34,623 [INFO] Season picked for Mire Chatman: 2001-02 — sleeping 3.8s
# 2025-12-09 17:17:38,382 [INFO] Autosaving due to processed_since_save >= save_every (normal path).
# 2025-12-09 17:17:38,402 [INFO] Saved stats (rows=86) to ndrafted/undrafted_college_stats.csv and summary (rows=100) to ndrafted/undrafted_summary.csv
# 2025-12-09 17:17:38,403 [INFO] [101/705] Scraping Lubos Barton (PLAYER_ID=12286)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 17:17:38,478 [INFO] Season picked for Lubos Barton: 2001-02 — sleeping 3.7s
# 2025-12-09 17:17:42,177 [INFO] [102/705] Scraping Damon Hancock (PLAYER_ID=12068)
# ...
# 2025-12-09 18:01:25,373 [INFO] [672/705] Scraping Isaac Jones (PLAYER_ID=1642403)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:01:25,634 [INFO] Season picked for Isaac Jones: 2005-06 — sleeping 3.9s
# 2025-12-09 18:01:29,506 [INFO] Long break after 672 players to avoid 429...
# 2025-12-09 18:01:39,509 [INFO] [673/705] Scraping David Jones (PLAYER_ID=1642357)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:01:39,605 [INFO] Season picked for David Jones: 1999-00 — sleeping 3.8s
# 2025-12-09 18:01:43,366 [INFO] [674/705] Scraping Keshad Johnson (PLAYER_ID=1642352)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:01:43,711 [INFO] Season picked for Keshad Johnson: 2023-24 — sleeping 3.6s
# 2025-12-09 18:01:47,324 [INFO] [675/705] Scraping Coleman Hawkins (PLAYER_ID=1641746)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:01:47,390 [INFO] Season picked for Coleman Hawkins: 2024-25 — sleeping 4.5s
# 2025-12-09 18:01:51,884 [INFO] [676/705] Scraping PJ Hall (PLAYER_ID=1641790)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:01:51,981 [INFO] Season picked for PJ Hall: 2023-24 — sleeping 3.5s
# 2025-12-09 18:01:55,531 [INFO] [677/705] Scraping Tyon Grant-Foster (PLAYER_ID=1642360)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:01:55,627 [INFO] Season picked for Tyon Grant-Foster: 2025-26 — sleeping 4.4s
# 2025-12-09 18:02:00,022 [INFO] [678/705] Scraping Trentyn Flowers (PLAYER_ID=1642280)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:02:00,094 [WARNING] No Totals table found for Trentyn Flowers (1642280) at https://www.sports-reference.com/cbb/players/trentyn-flowers-1.html: No tables found matching regex 'Totals'
# 2025-12-09 18:02:01,889 [INFO] [679/705] Scraping Ben Henshall (PLAYER_ID=1642916)
# 2025-12-09 18:02:01,963 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/ben-henshall-1.html — skipping this player.
# 2025-12-09 18:02:01,964 [INFO] No page for Ben Henshall (1642916), recorded as not found.
# 2025-12-09 18:02:03,652 [INFO] [680/705] Scraping Karter Knox (PLAYER_ID=1642909)
# 2025-12-09 18:02:03,875 [INFO] Season picked for Karter Knox: 2025-26 — sleeping 4.0s
# 2025-12-09 18:02:07,856 [INFO] [681/705] Scraping Yaxel Lendeborg (PLAYER_ID=1642865)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:02:07,925 [INFO] Season picked for Yaxel Lendeborg: 2025-26 — sleeping 4.0s
# 2025-12-09 18:02:11,940 [INFO] [682/705] Scraping RJ Luis Jr. (PLAYER_ID=1642961)
# 2025-12-09 18:02:12,009 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/rj-luis-jr-1.html — skipping this player.
# 2025-12-09 18:02:12,011 [INFO] No page for RJ Luis Jr. (1642961), recorded as not found.
# 2025-12-09 18:02:13,759 [INFO] [683/705] Scraping PJ Haggerty (PLAYER_ID=1642919)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:02:13,863 [INFO] Season picked for PJ Haggerty: 2025-26 — sleeping 4.3s
# 2025-12-09 18:02:18,131 [INFO] [684/705] Scraping Mackenzie Mgbako (PLAYER_ID=1642944)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:02:18,521 [WARNING] No Totals table found for Mackenzie Mgbako (1642944) at https://www.sports-reference.com/cbb/players/mackenzie-mgbako-1.html: No tables found matching regex 'Totals'
# 2025-12-09 18:02:20,090 [INFO] [685/705] Scraping Miles Byrd (PLAYER_ID=1642891)
# 2025-12-09 18:02:20,194 [INFO] Season picked for Miles Byrd: 2025-26 — sleeping 4.2s
# 2025-12-09 18:02:24,382 [INFO] [686/705] Scraping Vladislav Goldin (PLAYER_ID=1642884)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:02:24,725 [INFO] Season picked for Vladislav Goldin: 2024-25 — sleeping 3.9s
# 2025-12-09 18:02:28,655 [INFO] [687/705] Scraping Alex Condon (PLAYER_ID=1642960)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:02:28,730 [INFO] Season picked for Alex Condon: 2025-26 — sleeping 3.8s
# 2025-12-09 18:02:32,523 [INFO] [688/705] Scraping Eric Dixon (PLAYER_ID=1642915)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:02:32,608 [INFO] Season picked for Eric Dixon: 2024-25 — sleeping 3.6s
# 2025-12-09 18:02:36,245 [INFO] [689/705] Scraping Boogie Fland (PLAYER_ID=1642858)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:02:36,319 [INFO] Season picked for Boogie Fland: 2025-26 — sleeping 4.4s
# 2025-12-09 18:02:40,711 [INFO] [690/705] Scraping Jalon Moore (PLAYER_ID=1642922)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:02:40,848 [INFO] Season picked for Jalon Moore: 2024-25 — sleeping 3.8s
# 2025-12-09 18:02:44,693 [INFO] [691/705] Scraping Izan Almansa (PLAYER_ID=1641891)
# 2025-12-09 18:02:44,728 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/izan-almansa-1.html — skipping this player.
# 2025-12-09 18:02:44,729 [INFO] No page for Izan Almansa (1641891), recorded as not found.
# 2025-12-09 18:02:46,308 [INFO] [692/705] Scraping Grant Nelson (PLAYER_ID=1641761)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:02:46,377 [INFO] Season picked for Grant Nelson: 2024-25 — sleeping 4.0s
# 2025-12-09 18:02:50,351 [INFO] [693/705] Scraping Mark Sears (PLAYER_ID=1641813)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:02:50,415 [INFO] Season picked for Mark Sears: 2024-25 — sleeping 4.3s
# 2025-12-09 18:02:54,706 [INFO] [694/705] Scraping Milos Uzan (PLAYER_ID=1642870)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:02:54,795 [INFO] Season picked for Milos Uzan: 2025-26 — sleeping 4.2s
# 2025-12-09 18:02:58,978 [INFO] [695/705] Scraping Brice Williams (PLAYER_ID=1642924)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:02:59,071 [INFO] Season picked for Brice Williams: 2024-25 — sleeping 4.4s
# 2025-12-09 18:03:03,483 [INFO] [696/705] Scraping Darrion Williams (PLAYER_ID=1642963)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:03:03,581 [INFO] Season picked for Darrion Williams: 2025-26 — sleeping 3.7s
# 2025-12-09 18:03:07,235 [INFO] Long break after 696 players to avoid 429...
# 2025-12-09 18:03:17,242 [INFO] [697/705] Scraping Neoklis Avdalas (PLAYER_ID=1642921)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:03:17,353 [INFO] Season picked for Neoklis Avdalas: 2025-26 — sleeping 3.6s
# 2025-12-09 18:03:20,914 [INFO] [698/705] Scraping Hunter Sallis (PLAYER_ID=1642282)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:03:20,968 [INFO] Season picked for Hunter Sallis: 2024-25 — sleeping 4.2s
# 2025-12-09 18:03:25,218 [INFO] [699/705] Scraping Ryan Nembhard (PLAYER_ID=1642948)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:03:25,328 [INFO] Season picked for Ryan Nembhard: 2024-25 — sleeping 4.5s
# 2025-12-09 18:03:29,827 [INFO] [700/705] Scraping Otega Oweh (PLAYER_ID=1642923)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:03:29,944 [INFO] Season picked for Otega Oweh: 2025-26 — sleeping 4.0s
# 2025-12-09 18:03:33,975 [INFO] Autosaving due to processed_since_save >= save_every (normal path).
# 2025-12-09 18:03:34,002 [INFO] Saved stats (rows=579) to ndrafted/undrafted_college_stats.csv and summary (rows=673) to ndrafted/undrafted_summary.csv
# 2025-12-09 18:03:34,003 [INFO] [701/705] Scraping Dink Pate (PLAYER_ID=1641825)
# 2025-12-09 18:03:34,075 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/dink-pate-1.html — skipping this player.
# 2025-12-09 18:03:34,075 [INFO] No page for Dink Pate (1641825), recorded as not found.
# 2025-12-09 18:03:35,834 [INFO] [702/705] Scraping Tahaad Pettiford (PLAYER_ID=1642861)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:03:35,929 [INFO] Season picked for Tahaad Pettiford: 2025-26 — sleeping 4.3s
# 2025-12-09 18:03:40,243 [INFO] [703/705] Scraping Labaron Philon (PLAYER_ID=1642889)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:03:40,308 [INFO] Season picked for Labaron Philon: 2025-26 — sleeping 3.5s
# 2025-12-09 18:03:43,847 [INFO] [704/705] Scraping Michael Ruzic (PLAYER_ID=1642913)
# 2025-12-09 18:03:43,904 [WARNING] 404 Not Found: https://www.sports-reference.com/cbb/players/michael-ruzic-1.html — skipping this player.
# 2025-12-09 18:03:43,905 [INFO] No page for Michael Ruzic (1642913), recorded as not found.
# 2025-12-09 18:03:45,632 [INFO] [705/705] Scraping Tamar Bates (PLAYER_ID=1642926)
# /var/folders/b9/7xp5dt9d5nd0hct357z94wgh0000gn/T/ipykernel_28164/1930703047.py:335: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(resp.text, match="Totals", flavor="lxml")
# 2025-12-09 18:03:45,699 [INFO] Season picked for Tamar Bates: 2024-25 — sleeping 4.5s
# 2025-12-09 18:03:50,161 [INFO] Final save of remaining rows at end of run.
# 2025-12-09 18:03:50,179 [INFO] Saved stats (rows=582) to ndrafted/undrafted_college_stats.csv and summary (rows=678) to ndrafted/undrafted_summary.csv
