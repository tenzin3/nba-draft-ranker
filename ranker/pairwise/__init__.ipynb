# %%
import pandas as pd
from pathlib import Path


root_dir = Path.cwd().parent.parent
dataset_path = root_dir /"outputs" / "nba_college_selected_features.csv"

df = pd.read_csv(dataset_path)
print(df.columns)
print(df.shape)
# Out:
# Index(['player_name', 'OVERALL_PICK', 'SEASON', 'Totals_FG', 'Totals_FT',
#        'Totals_TRB', 'Totals_BLK', 'Totals_STL', 'Totals_TOV', 'Totals_PF',
#        'Shooting_FG%', 'MP', 'Age'],
#       dtype='object')
# (888, 13)

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Define a function for pairwise ranking
def pairwise_ranking(data, feature_columns, target_column):
    """
    Perform pairwise ranking based on the given features and target.

    Parameters:
        data (pd.DataFrame): The input data containing features and target.
        feature_columns (list): List of feature column names.
        target_column (str): The target column name.

    Returns:
        pd.DataFrame: DataFrame with pairwise ranking scores.
    """
    # Normalize the features
    scaler = MinMaxScaler()
    data[feature_columns] = scaler.fit_transform(data[feature_columns])

    # Compute pairwise differences
    pairwise_scores = []
    for i in range(len(data)):
        for j in range(len(data)):
            if i != j:
                diff = data.loc[i, feature_columns] - data.loc[j, feature_columns]
                score = np.dot(diff, diff)  # Squared Euclidean distance
                pairwise_scores.append({
                    'Player1': data.loc[i, target_column],
                    'Player2': data.loc[j, target_column],
                    'Score': score
                })

    return pd.DataFrame(pairwise_scores)

# Example usage
# Load your dataset (replace 'your_dataset.csv' with the actual file path)
data = pd.read_csv('path_to_your_data.csv')

# Define feature columns and target column
feature_columns = ['feature1', 'feature2', 'feature3']  # Replace with actual feature names
target_column = 'player_name'  # Replace with the actual target column name

# Perform pairwise ranking
ranked_data = pairwise_ranking(data, feature_columns, target_column)

# Display the ranked data
print(ranked_data.head())
